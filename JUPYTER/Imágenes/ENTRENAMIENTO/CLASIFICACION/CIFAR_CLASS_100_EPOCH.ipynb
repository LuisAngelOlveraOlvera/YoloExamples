# %%
# Verificar que estamos usando el GPU de la laptop:
# !pip install torch
import torch

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
tensor = torch.randn(2, 2).to(device)
print(tensor.device)

print(torch.cuda.device_count())  # Imprime el número de GPUs disponibles
# Out:
# Requirement already satisfied: torch in c:\users\user\anaconda3\lib\site-packages (2.4.0+cu118)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\user\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\user\anaconda3\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from torch) (69.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# cuda:0
# 1

# %%
# !nvidia-smi
# Out:
# Sun Sep 29 20:28:20 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.76                 Driver Version: 560.76         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   52C    P8             12W /  117W |     125MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A     14516      C   C:\Users\User\anaconda3\python.exe          N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Instalar Kaggle
# !pip install -q kaggle

# Ruta donde se encuentra tu archivo kaggle.json
kaggle_json_path = r'C:\Users\User\Documents\kaggle.json'

# %%
import os  # For path manipulation
import shutil  # For file movement (more portable)

# Instalar Kaggle
# !pip install -q kaggle

# Ruta donde se encuentra tu archivo kaggle.json
kaggle_json_path = r'C:\Users\User\Documents\kaggle.json'

# Crear el directorio .kaggle si no existe
if not os.path.exists(os.path.expanduser('~/.kaggle')):
    os.makedirs(os.path.expanduser('~/.kaggle'))

# Mover kaggle.json al directorio .kaggle
dest_path = os.path.join(os.path.expanduser('~/.kaggle'), 'kaggle.json')
shutil.move(kaggle_json_path, dest_path)

# Asegurarse de que el archivo kaggle.json tiene permisos correctos
os.chmod(dest_path, 0o600)

# Descargar el dataset CIFAR-10 desde Kaggle
# !kaggle competitions download -c cifar-10
# Out:
# Downloading cifar-10.zip to C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE
#   0%|          | 0.00/715M [00:00<?, ?B/s]
#   0%|          | 1.00M/715M [00:00<02:09, 5.77MB/s]
#   1%|          | 5.00M/715M [00:00<00:42, 17.6MB/s]
#   1%|1         | 8.00M/715M [00:00<00:39, 18.9MB/s]
#   1%|1         | 10.0M/715M [00:00<00:39, 18.7MB/s]
#   2%|1         | 12.0M/715M [00:00<00:39, 18.5MB/s]
#   2%|1         | 14.0M/715M [00:00<00:39, 18.5MB/s]
#   2%|2         | 16.0M/715M [00:00<00:39, 18.3MB/s]
#   3%|2         | 18.0M/715M [00:01<00:39, 18.4MB/s]
#   3%|2         | 20.0M/715M [00:01<00:39, 18.3MB/s]
#   3%|3         | 22.0M/715M [00:01<00:39, 18.3MB/s]
#   3%|3         | 24.0M/715M [00:01<00:39, 18.3MB/s]
#   4%|3         | 26.0M/715M [00:01<00:39, 18.2MB/s]
#   4%|3         | 28.0M/715M [00:01<00:39, 18.2MB/s]
#   4%|4         | 30.0M/715M [00:01<00:39, 18.3MB/s]
#   4%|4         | 32.0M/715M [00:01<00:39, 18.3MB/s]
#   5%|4         | 34.0M/715M [00:01<00:39, 18.2MB/s]
#   5%|5         | 36.0M/715M [00:02<00:40, 17.7MB/s]
#   5%|5         | 38.0M/715M [00:02<00:38, 18.5MB/s]
#   6%|5         | 40.0M/715M [00:02<00:38, 18.4MB/s]
#   6%|5         | 42.0M/715M [00:02<00:38, 18.3MB/s]
#   6%|6         | 44.0M/715M [00:02<00:38, 18.3MB/s]
#   6%|6         | 46.0M/715M [00:02<00:38, 18.3MB/s]
#   7%|6         | 48.0M/715M [00:02<00:38, 18.3MB/s]
#   7%|6         | 50.0M/715M [00:02<00:38, 18.3MB/s]
#  94%|#########4| 673M/715M [00:40<00:02, 18.2MB/s]
#  94%|#########4| 675M/715M [00:40<00:02, 18.2MB/s]
#  95%|#########4| 677M/715M [00:40<00:02, 18.3MB/s]
#  95%|#########4| 679M/715M [00:40<00:02, 18.4MB/s]
#  95%|#########5| 681M/715M [00:41<00:01, 18.4MB/s]
#  95%|#########5| 683M/715M [00:41<00:01, 18.3MB/s]
#  96%|#########5| 685M/715M [00:41<00:01, 18.4MB/s]
#  96%|#########6| 687M/715M [00:41<00:01, 18.3MB/s]
#  96%|#########6| 689M/715M [00:41<00:01, 18.3MB/s]
#  97%|#########6| 691M/715M [00:41<00:01, 18.2MB/s]
#  97%|#########6| 693M/715M [00:41<00:01, 18.3MB/s]
#  97%|#########7| 695M/715M [00:41<00:01, 18.1MB/s]
#  97%|#########7| 697M/715M [00:42<00:01, 18.3MB/s]
#  98%|#########7| 699M/715M [00:42<00:00, 18.3MB/s]
#  98%|#########7| 701M/715M [00:42<00:00, 18.4MB/s]
#  98%|#########8| 703M/715M [00:42<00:00, 18.3MB/s]
#  99%|#########8| 705M/715M [00:42<00:00, 18.3MB/s]
#  99%|#########8| 707M/715M [00:42<00:00, 18.3MB/s]
#  99%|#########9| 709M/715M [00:42<00:00, 18.1MB/s]
#  99%|#########9| 711M/715M [00:42<00:00, 18.3MB/s]
# 100%|#########9| 713M/715M [00:42<00:00, 18.3MB/s]
# 100%|#########9| 715M/715M [00:43<00:00, 18.3MB/s]
# 100%|##########| 715M/715M [00:43<00:00, 17.4MB/s]

# %%
import os
import zipfile

# Ruta completa al archivo .zip
zip_file = r"C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\cifar-10.zip"

# Directorio donde se extraerán los archivos
extract_dir = "cifar-10_extraido"

# Crear el directorio de extracción si no existe
if not os.path.exists(extract_dir):
    os.makedirs(extract_dir)

# Extraer el archivo .zip
try:
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(path=extract_dir)
    print(f"Archivo {zip_file} extraído correctamente en {extract_dir}")
except Exception as e:
    print(f"Error al extraer el archivo: {e}")
# Out:
# Archivo C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\cifar-10.zip extraído correctamente en cifar-10_extraido

# %%
import os
import zipfile

# Ruta completa al archivo .zip
zip_file = r"C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\cifar-10.zip"

# Directorio donde se extraerán los archivos
extract_dir = "cifar-10_extraido"

# Crear el directorio de extracción si no existe
if not os.path.exists(extract_dir):
    os.makedirs(extract_dir)

# Extraer el archivo .zip
try:
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(path=extract_dir)
    print(f"Archivo {zip_file} extraído correctamente en {extract_dir}")
except Exception as e:
    print(f"Error al extraer el archivo: {e}")

# %%
# !pip install py7zr

import py7zr
import os

# Ruta del archivo 7z
train_archive = r"C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\cifar-10_extraido\train.7z"

# Directorio donde se extraerán los archivos
extract_dir = r"C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar"

# Verifica si la carpeta destino existe, si no, la crea
if not os.path.exists(extract_dir):
    os.makedirs(extract_dir)

# Descomprimir el archivo .7z en la carpeta destino
with py7zr.SevenZipFile(train_archive, mode='r') as z:
    z.extractall(path=extract_dir)

print(f"Archivos extraídos en {extract_dir}")
# Out:
# Collecting py7zr
#   Downloading py7zr-0.22.0-py3-none-any.whl.metadata (16 kB)
# Collecting texttable (from py7zr)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr)
#   Downloading pycryptodomex-3.20.0-cp35-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting pyzstd>=0.15.9 (from py7zr)
#   Downloading pyzstd-0.16.1-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr)
#   Downloading pyppmd-1.1.0-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr)
#   Downloading pybcj-1.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr)
#   Downloading inflate64-1.0.0-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Collecting brotli>=1.1.0 (from py7zr)
#   Downloading Brotli-1.1.0-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from py7zr) (5.9.0)
# Downloading py7zr-0.22.0-py3-none-any.whl (67 kB)
#    ---------------------------------------- 0.0/67.9 kB ? eta -:--:--
#    ------------------ --------------------- 30.7/67.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 67.9/67.9 kB 915.3 kB/s eta 0:00:00
# Downloading Brotli-1.1.0-cp312-cp312-win_amd64.whl (357 kB)
#    ---------------------------------------- 0.0/357.3 kB ? eta -:--:--
#    ---------- ----------------------------- 92.2/357.3 kB 2.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 204.8/357.3 kB 2.1 MB/s eta 0:00:01
#    -------------------------- ------------- 235.5/357.3 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 357.3/357.3 kB 2.2 MB/s eta 0:00:00
# Downloading inflate64-1.0.0-cp312-cp312-win_amd64.whl (35 kB)
# Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Downloading pybcj-1.0.2-cp312-cp312-win_amd64.whl (24 kB)
# Downloading pycryptodomex-3.20.0-cp35-abi3-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.8 MB 9.9 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/1.8 MB 8.3 MB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.8 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 9.3 MB/s eta 0:00:00
# Downloading pyppmd-1.1.0-cp312-cp312-win_amd64.whl (46 kB)
#    ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#    ---------------------------------------- 46.2/46.2 kB 2.4 MB/s eta 0:00:00
# Downloading pyzstd-0.16.1-cp312-cp312-win_amd64.whl (244 kB)
#    ---------------------------------------- 0.0/244.7 kB ? eta -:--:--
#    ---------------------------------------- 244.7/244.7 kB 7.3 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, brotli, pyzstd, pyppmd, pycryptodomex, pybcj, multivolumefile, inflate64, py7zr
#   Attempting uninstall: brotli
#     Found existing installation: Brotli 1.0.9
#     Uninstalling Brotli-1.0.9:
#       Successfully uninstalled Brotli-1.0.9
# Successfully installed brotli-1.1.0 inflate64-1.0.0 multivolumefile-0.2.3 py7zr-0.22.0 pybcj-1.0.2 pycryptodomex-3.20.0 pyppmd-1.1.0 pyzstd-0.16.1 texttable-1.7.0
# Archivos extraídos en C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar

# %%
# !pip install pillow

# %%
import os
import random
from PIL import Image
import matplotlib.pyplot as plt


train_dir = r"C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\train"

# Obtener una lista de archivos de imagen
image_files = [f for f in os.listdir(train_dir) if os.path.isfile(os.path.join(train_dir, f))]

# Seleccionar 5 imágenes aleatoriamente
random_images = random.sample(image_files, 5)

# Mostrar las imágenes y sus dimensiones
plt.figure(figsize=(10,5))
for i, image_file in enumerate(random_images):
    img = Image.open(os.path.join(train_dir, image_file))
    width, height = img.size
    print(f"Imagen: {image_file}, Tamaño: {width}x{height}")
    plt.subplot(1, 5, i + 1)
    plt.imshow(img)
    plt.axis('off')
    plt.title(image_file)
plt.show()
# Out:
# Imagen: 2620.png, Tamaño: 32x32
# Imagen: 31207.png, Tamaño: 32x32
# Imagen: 24037.png, Tamaño: 32x32
# Imagen: 27355.png, Tamaño: 32x32
# Imagen: 13657.png, Tamaño: 32x32

# %%
# 3. Tamaño de elementos para carpeta train
import os

# ruta de la carpeta
dir_path = r"C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\train"
count = 0
# Itera dentro de la carpeta, es un contador
for path in os.listdir(dir_path):
    # verifica si la ruta actual es un arhico
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('Número total de elementos:', count)
# Out:
# Número total de elementos: 50000

# %%
# 4. Análisis rápido de las etiquetas de trainLabels.csv
import pandas as pd

# Cargar el CSV
labels_df = pd.read_csv(r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\cifar-10_extraido\trainLabels.csv')

labels_df.head()
# Out:
#    id       label
# 0   1        frog
# 1   2       truck
# 2   3       truck
# 3   4        deer
# 4   5  automobile

# %%
# 3. Crear listas de imágenes y etiquetas
from sklearn.model_selection import train_test_split
import shutil
import os

# Asegurarse de que el ID esté correctamente formateado para coincidir con los nombres de archivo
images = labels_df['id'].apply(lambda x: f'{x}.png').values
labels = labels_df['label'].values

# Dividir en entrenamientos y validación
train_imgs, val_imgs, train_labels, val_labels = train_test_split(images, labels, test_size=0.2, stratify=labels, random_state=42)

# Crear las carpetas de entrenamiento y validación
train_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\train'
val_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\val'

# Crear carpetas por clase dentro de val y train
for label in labels_df["label"].unique():
    os.makedirs(os.path.join(train_path, str(label)), exist_ok=True)
    os.makedirs(os.path.join(val_path, str(label)), exist_ok=True)

train_count = 0
val_count = 0

# Mover las imágenes de entrenamiento
for img, label in zip(train_imgs, train_labels):
    img_src = rf'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\train\{img}'
    img_dst = os.path.join(train_path, str(label), img)
    if os.path.exists(img_src):  # Verificar si la imagen existe
        shutil.move(img_src, img_dst)
        train_count += 1
    else:
        print(f'Imagen no encontrada: {img_src}')

print(f'Número de imágenes movidas a entrenamiento: {train_count}')

# Mover las imágenes de validación
for img, label in zip(val_imgs, val_labels):
    img_src = rf'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\train\{img}'
    img_dst = os.path.join(val_path, str(label), img)
    if os.path.exists(img_src):  # Verificar si la imagen existe
        shutil.move(img_src, img_dst)
        val_count += 1
    else:
        print(f'Imagen no encontrada: {img_src}')

print(f'Número de imágenes movidas a validación: {val_count}')
# Out:
# Número de imágenes movidas a entrenamiento: 40000
# Número de imágenes movidas a validación: 10000

# %%
# 3.1 Tamaño de elementos para carpeta train
import os

# ruta de la carpeta
dir_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\train\bird'


count = 0
# Itera dentro de la carpeta, es un contador
for path in os.listdir(dir_path):
    # verifica si la ruta actual es un arhico
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('Número total de elementos:', count)
# Out:
# Número total de elementos: 4000

# %%
# 3.1 Tamaño de elementos para carpeta train
import os

# ruta de la carpeta
dir_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\val\cat'


count = 0
# Itera dentro de la carpeta, es un contador
for path in os.listdir(dir_path):
    # verifica si la ruta actual es un arhico
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('Número total de elementos:', count)
# Out:
# Número total de elementos: 1000

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\user\anaconda3\lib\site-packages (8.2.77)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (3.8.4)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (2.32.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (2.4.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (0.19.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (69.5.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
from ultralytics import YOLO

# Cargar el modelo yolov8n-cls.pt para clasificación
model = YOLO('yolov8n-cls.pt')
# Entrenar el modelo con CIFAR-10
model.train(data=r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar', epochs=100, imgsz=32)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n-cls.pt to 'yolov8n-cls.pt'...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 15.7MB/s]
# New https://pypi.org/project/ultralytics/8.3.0 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.77  Python-3.12.6 torch-2.4.0 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# engine\trainer: task=classify, mode=train, model=yolov8n-cls.pt, data=C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\dataset_sin_ordenar, epochs=100, time=None, patience=100, batch=16, imgsz=32, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\classify\train
# train: C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\dataset_sin_ordenar\train... found 40000 images in 10 classes
# val: C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\dataset_sin_ordenar\val... found 10000 images in 10 classes
# test: None...
# Overriding model.yaml nc=1000 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    343050  ultralytics.nn.modules.head.Classify         [256, 10]
# YOLOv8n-cls summary: 99 layers, 1,451,098 parameters, 1,451,098 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/luisangelolveraolvera/general/17ec1a1b80c0485b940abb6cfc0ca0cd
#
# COMET INFO: Couldn't find a Git repository in 'C:\\Users\\User\\Documents\\JUPYTER_LOCAL\\IMÁGENES_ENTRENAMIENTO\\CLASIFICACIÓN\\CIFAR_KAGGLE' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 16.9MB/s]
# AMP: checks passed
# C:\Users\User\anaconda3\Lib\site-packages\ultralytics\engine\trainer.py:271: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.amp)
# train: Scanning C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\train... 40000 images, 0 corrupt: 100%|██████████| 40000/40000 [00:36<00:00, 1096.88it/s]
# train: New cache created: C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\dataset_sin_ordenar\train.cache
# val: Scanning C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\val... 10000 images, 0 corrupt: 100%|██████████| 10000/10000 [00:08<00:00, 1171.07it/s]
# val: New cache created: C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\dataset_sin_ordenar\val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 32 train, 32 val
# Using 8 dataloader workers
# Logging results to runs\classify\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100     0.132G      1.961         16         32: 100%|██████████| 2500/2500 [01:25<00:00, 29.07it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:04<00:00, 64.77it/s]
#                    all       0.47      0.925
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100     0.109G      1.879         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.32it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:04<00:00, 76.89it/s]
#                    all      0.486      0.913
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100     0.109G      1.886         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.93it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:04<00:00, 77.36it/s]
#                    all       0.56      0.932
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100     0.109G      1.569         16         32: 100%|██████████| 2500/2500 [01:09<00:00, 36.11it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 79.82it/s]
#                    all      0.635      0.962
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100     0.109G      1.409         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.70it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 84.80it/s]
#                    all      0.654      0.969
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100     0.109G      1.348         16         32: 100%|██████████| 2500/2500 [01:09<00:00, 35.81it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 81.28it/s]
#                    all      0.684       0.97
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100     0.109G      1.303         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 36.92it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.19it/s]
#                    all      0.669      0.972
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100     0.109G      1.279         16         32: 100%|██████████| 2500/2500 [01:08<00:00, 36.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.69it/s]
#                    all      0.704      0.976
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100     0.109G       1.26         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 37.17it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.29it/s]
#                    all      0.705      0.978
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100     0.109G      1.242         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 36.77it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.23it/s]
#                    all      0.713      0.978
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100     0.109G      1.222         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 37.28it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.00it/s]
#                    all      0.695      0.977
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100     0.109G      1.246         16         32: 100%|██████████| 2500/2500 [01:05<00:00, 38.17it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 86.94it/s]
#                    all      0.704      0.977
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100     0.109G      1.215         16         32: 100%|██████████| 2500/2500 [01:05<00:00, 37.88it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 87.17it/s]
#                    all      0.712       0.97
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100     0.109G      1.206         16         32: 100%|██████████| 2500/2500 [01:06<00:00, 37.51it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.88it/s]
#                    all      0.722      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100     0.109G      1.193         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 37.00it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 86.07it/s]
#                    all       0.71      0.982
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100     0.109G      1.191         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 37.17it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.61it/s]
#                    all      0.727      0.983
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100     0.109G       1.18         16         32: 100%|██████████| 2500/2500 [01:06<00:00, 37.67it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 86.62it/s]
#                    all      0.724      0.982
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100     0.109G      1.185         16         32: 100%|██████████| 2500/2500 [01:06<00:00, 37.70it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 86.98it/s]
#                    all      0.724      0.975
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100     0.109G      1.158         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 37.29it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 88.02it/s]
#                    all      0.729      0.983
#       Epoch    GPU_mem       loss  Instances       Size
#      20/100     0.109G      1.146         16         32: 100%|██████████| 2500/2500 [01:06<00:00, 37.47it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 87.68it/s]
#                    all      0.737      0.983
#       Epoch    GPU_mem       loss  Instances       Size
#      21/100     0.109G      1.142         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 36.88it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 79.13it/s]
#                    all      0.737      0.982
#
#       Epoch    GPU_mem       loss  Instances       Size
#      22/100     0.109G      1.138         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 36.94it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 87.55it/s]
#                    all       0.74      0.982
#       Epoch    GPU_mem       loss  Instances       Size
#      23/100     0.109G      1.108         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 37.27it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 89.62it/s]
#                    all      0.734      0.983
#
#       Epoch    GPU_mem       loss  Instances       Size
#      24/100     0.109G      1.114         16         32: 100%|██████████| 2500/2500 [01:06<00:00, 37.68it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 88.06it/s]
#                    all      0.735      0.979
#       Epoch    GPU_mem       loss  Instances       Size
#      25/100     0.109G       1.12         16         32: 100%|██████████| 2500/2500 [01:06<00:00, 37.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.16it/s]
#                    all      0.747      0.982
#       Epoch    GPU_mem       loss  Instances       Size
#      26/100     0.109G      1.143         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 37.30it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 87.78it/s]
#                    all      0.753      0.984
#       Epoch    GPU_mem       loss  Instances       Size
#      27/100     0.109G       1.11         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 37.22it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.95it/s]
#                    all      0.759      0.985
#       Epoch    GPU_mem       loss  Instances       Size
#      28/100     0.109G      1.105         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 37.11it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 86.73it/s]
#                    all       0.76      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#      29/100     0.109G      1.112         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 37.07it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.89it/s]
#                    all      0.761      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#      30/100     0.109G       1.11         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 36.99it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.01it/s]
#                    all      0.762      0.985
#       Epoch    GPU_mem       loss  Instances       Size
#      31/100     0.109G      1.099         16         32: 100%|██████████| 2500/2500 [01:08<00:00, 36.27it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.22it/s]
#                    all      0.761      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#      32/100     0.109G      1.084         16         32: 100%|██████████| 2500/2500 [01:08<00:00, 36.26it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 86.40it/s]
#                    all      0.761      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      33/100     0.109G      1.079         16         32: 100%|██████████| 2500/2500 [01:07<00:00, 36.89it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 86.73it/s]
#                    all      0.762      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      34/100     0.109G       1.07         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.68it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.10it/s]
#                    all      0.764      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      35/100     0.109G      1.055         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.84it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.52it/s]
#                    all      0.764      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      36/100     0.109G      1.055         16         32: 100%|██████████| 2500/2500 [01:13<00:00, 34.21it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 84.28it/s]
#                    all      0.765      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#      37/100     0.109G       1.04         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.80it/s]
#                    all      0.766      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      38/100     0.109G      1.068         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.40it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.78it/s]
#                    all      0.767      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#      39/100     0.109G      1.055         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 84.77it/s]
#                    all      0.769      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#      40/100     0.109G      1.046         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.67it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.10it/s]
#                    all      0.769      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#      41/100     0.109G       1.04         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:04<00:00, 76.25it/s]
#                    all       0.77      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      42/100     0.109G       1.03         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 35.10it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.39it/s]
#                    all      0.769      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      43/100     0.109G      1.012         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.42it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.83it/s]
#                    all       0.77      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#      44/100     0.109G      1.032         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 35.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.93it/s]
#                    all       0.77      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      45/100     0.109G      1.009         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.69it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 81.33it/s]
#                    all      0.771      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      46/100     0.109G      1.021         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.77it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 84.17it/s]
#                    all      0.771      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      47/100     0.109G       1.01         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.47it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 87.72it/s]
#                    all      0.772      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#      48/100     0.109G      1.026         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 35.17it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.40it/s]
#                    all      0.773      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      49/100     0.109G       1.02         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.72it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.40it/s]
#                    all      0.774      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#      50/100     0.109G     0.9913         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.26it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.04it/s]
#                    all      0.775      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      51/100     0.109G     0.9781         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.67it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.95it/s]
#                    all      0.775      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      52/100     0.109G     0.9847         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.94it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.36it/s]
#                    all      0.775      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      53/100     0.109G     0.9692         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.88it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.11it/s]
#                    all      0.776      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      54/100     0.109G      1.002         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.80it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:04<00:00, 77.89it/s]
#                    all      0.777      0.988
#       Epoch    GPU_mem       loss  Instances       Size
#      55/100     0.109G     0.9913         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.50it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.83it/s]
#                    all      0.778      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#      56/100     0.109G     0.9724         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.88it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 86.94it/s]
#                    all      0.779      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#      57/100     0.109G     0.9794         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.28it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.29it/s]
#                    all      0.779      0.988
#       Epoch    GPU_mem       loss  Instances       Size
#      58/100     0.109G     0.9587         16         32: 100%|██████████| 2500/2500 [01:13<00:00, 33.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.91it/s]
#                    all      0.779      0.988
#       Epoch    GPU_mem       loss  Instances       Size
#      59/100     0.109G     0.9667         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.38it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 84.27it/s]
#                    all       0.78      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#      60/100     0.109G     0.9631         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.45it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 86.50it/s]
#                    all      0.779      0.988
#       Epoch    GPU_mem       loss  Instances       Size
#      61/100     0.109G     0.9449         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 35.20it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 88.13it/s]
#                    all       0.78      0.988
#       Epoch    GPU_mem       loss  Instances       Size
#      62/100     0.109G     0.9507         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.40it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 87.67it/s]
#                    all      0.779      0.988
#       Epoch    GPU_mem       loss  Instances       Size
#      63/100     0.109G     0.9388         16         32: 100%|██████████| 2500/2500 [01:12<00:00, 34.68it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 80.18it/s]
#                    all      0.779      0.988
#       Epoch    GPU_mem       loss  Instances       Size
#      64/100     0.109G     0.9283         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.76it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.28it/s]
#                    all       0.78      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#      65/100     0.109G     0.9247         16         32: 100%|██████████| 2500/2500 [01:09<00:00, 35.72it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 86.95it/s]
#                    all      0.781      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      66/100     0.109G     0.9327         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 35.14it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.97it/s]
#                    all      0.781      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      67/100     0.109G     0.9239         16         32: 100%|██████████| 2500/2500 [01:09<00:00, 35.76it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 88.12it/s]
#                    all      0.779      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      68/100     0.109G      0.903         16         32: 100%|██████████| 2500/2500 [01:09<00:00, 35.88it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 87.26it/s]
#                    all      0.779      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      69/100     0.109G     0.8998         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.66it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.45it/s]
#                    all      0.779      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      70/100     0.109G      0.895         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.35it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 87.20it/s]
#                    all      0.779      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#      71/100     0.109G     0.9086         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.82it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.15it/s]
#                    all      0.779      0.985
#       Epoch    GPU_mem       loss  Instances       Size
#      72/100     0.109G     0.8835         16         32: 100%|██████████| 2500/2500 [01:02<00:00, 39.69it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 95.76it/s]
#                    all       0.78      0.985
#       Epoch    GPU_mem       loss  Instances       Size
#      73/100     0.109G     0.8838         16         32: 100%|██████████| 2500/2500 [01:08<00:00, 36.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 81.50it/s]
#                    all      0.778      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      74/100     0.109G     0.8749         16         32: 100%|██████████| 2500/2500 [01:09<00:00, 36.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:04<00:00, 75.90it/s]
#                    all      0.779      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      75/100     0.109G     0.8603         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.54it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.93it/s]
#                    all      0.779      0.986
#       Epoch    GPU_mem       loss  Instances       Size
#      76/100     0.109G     0.8567         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 35.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.08it/s]
#                    all      0.778      0.985
#       Epoch    GPU_mem       loss  Instances       Size
#      77/100     0.109G     0.8578         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.44it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:04<00:00, 77.93it/s]
#                    all      0.777      0.984
#       Epoch    GPU_mem       loss  Instances       Size
#      78/100     0.109G     0.8511         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.95it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.43it/s]
#                    all      0.777      0.984
#       Epoch    GPU_mem       loss  Instances       Size
#      79/100     0.109G     0.8404         16         32: 100%|██████████| 2500/2500 [01:02<00:00, 40.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 91.33it/s]
#                    all      0.778      0.984
#       Epoch    GPU_mem       loss  Instances       Size
#      80/100     0.109G     0.8537         16         32: 100%|██████████| 2500/2500 [01:04<00:00, 38.85it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 89.32it/s]
#                    all      0.778      0.984
#       Epoch    GPU_mem       loss  Instances       Size
#      81/100     0.109G     0.8421         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.35it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.02it/s]
#                    all      0.778      0.984
#       Epoch    GPU_mem       loss  Instances       Size
#      82/100     0.109G     0.8339         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.22it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.20it/s]
#                    all      0.778      0.984
#       Epoch    GPU_mem       loss  Instances       Size
#      83/100     0.109G      0.827         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.98it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 81.49it/s]
#                    all       0.78      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#      84/100     0.109G     0.8324         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.41it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 80.05it/s]
#                    all      0.782      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#      85/100     0.109G     0.8166         16         32: 100%|██████████| 2500/2500 [01:09<00:00, 35.91it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 86.36it/s]
#                    all      0.785       0.99
#       Epoch    GPU_mem       loss  Instances       Size
#      86/100     0.109G     0.8143         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.34it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.83it/s]
#                    all      0.787       0.99
#       Epoch    GPU_mem       loss  Instances       Size
#      87/100     0.109G     0.8135         16         32: 100%|██████████| 2500/2500 [01:02<00:00, 39.70it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 94.56it/s]
#                    all      0.789      0.991
#       Epoch    GPU_mem       loss  Instances       Size
#      88/100     0.109G     0.7983         16         32: 100%|██████████| 2500/2500 [01:03<00:00, 39.49it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 91.68it/s]
#                    all      0.789      0.991
#       Epoch    GPU_mem       loss  Instances       Size
#      89/100     0.109G     0.7963         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.26it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.61it/s]
#                    all       0.79      0.991
#       Epoch    GPU_mem       loss  Instances       Size
#      90/100     0.109G     0.7894         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.31it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.35it/s]
#                    all      0.791      0.991
#       Epoch    GPU_mem       loss  Instances       Size
#      91/100     0.109G      0.777         16         32: 100%|██████████| 2500/2500 [01:01<00:00, 40.59it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 94.45it/s]
#                    all      0.792      0.991
#       Epoch    GPU_mem       loss  Instances       Size
#      92/100     0.109G      0.779         16         32: 100%|██████████| 2500/2500 [01:03<00:00, 39.67it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 91.12it/s]
#                    all      0.792       0.99
#       Epoch    GPU_mem       loss  Instances       Size
#      93/100     0.109G     0.7753         16         32: 100%|██████████| 2500/2500 [01:05<00:00, 37.89it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 84.29it/s]
#                    all      0.793      0.989
#       Epoch    GPU_mem       loss  Instances       Size
#      94/100     0.109G     0.7677         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.95it/s]
#                    all      0.795      0.989
#       Epoch    GPU_mem       loss  Instances       Size
#      95/100     0.109G     0.7572         16         32: 100%|██████████| 2500/2500 [01:13<00:00, 34.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 82.13it/s]
#                    all      0.796      0.989
#       Epoch    GPU_mem       loss  Instances       Size
#      96/100     0.109G     0.7515         16         32: 100%|██████████| 2500/2500 [01:11<00:00, 34.97it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 80.39it/s]
#                    all      0.797      0.989
#       Epoch    GPU_mem       loss  Instances       Size
#      97/100     0.109G     0.7326         16         32: 100%|██████████| 2500/2500 [01:10<00:00, 35.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.27it/s]
#                    all      0.798      0.989
#       Epoch    GPU_mem       loss  Instances       Size
#      98/100     0.109G     0.7381         16         32: 100%|██████████| 2500/2500 [01:08<00:00, 36.24it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:04<00:00, 77.78it/s]
#                    all      0.799       0.99
#       Epoch    GPU_mem       loss  Instances       Size
#      99/100     0.109G     0.7262         16         32: 100%|██████████| 2500/2500 [01:09<00:00, 35.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 85.93it/s]
#                    all      0.801       0.99
#       Epoch    GPU_mem       loss  Instances       Size
#     100/100     0.109G     0.7205         16         32: 100%|██████████| 2500/2500 [01:09<00:00, 35.94it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 83.07it/s]
#                    all      0.801      0.989
#
# 100 epochs completed in 2.068 hours.
# Optimizer stripped from runs\classify\train\weights\last.pt, 3.0MB
# Optimizer stripped from runs\classify\train\weights\best.pt, 3.0MB
#
# Validating runs\classify\train\weights\best.pt...
# Ultralytics YOLOv8.2.77  Python-3.12.6 torch-2.4.0 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1,447,690 parameters, 0 gradients, 3.3 GFLOPs
# train: C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\dataset_sin_ordenar\train... found 40000 images in 10 classes
# val: C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\dataset_sin_ordenar\val... found 10000 images in 10 classes
# test: None...
#                classes   top1_acc   top5_acc: 100%|██████████| 313/313 [00:03<00:00, 96.10it/s]
#                    all      0.801      0.989
# Speed: 0.0ms preprocess, 0.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs\classify\train
# Results saved to runs\classify\train
# COMET ERROR: We failed to read file runs\classify\train\F1_curve.png for uploading.
# Please double-check the file path and permissions
# COMET ERROR: We failed to read file runs\classify\train\P_curve.png for uploading.
# Please double-check the file path and permissions
# COMET ERROR: We failed to read file runs\classify\train\R_curve.png for uploading.
# Please double-check the file path and permissions
# COMET ERROR: We failed to read file runs\classify\train\PR_curve.png for uploading.
# Please double-check the file path and permissions
# COMET ERROR: We failed to read file runs\classify\train\labels.jpg for uploading.
# Please double-check the file path and permissions
# COMET ERROR: We failed to read file runs\classify\train\labels_correlogram.jpg for uploading.
# Please double-check the file path and permissions
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : solar_truck_912
# COMET INFO:     url                   : https://www.comet.com/luisangelolveraolvera/general/17ec1a1b80c0485b940abb6cfc0ca0cd
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     lr/pg0 [101]                : (0.0001990000000000001, 0.009800693066666666)
# COMET INFO:     lr/pg1 [101]                : (0.0001990000000000001, 0.009800693066666666)
# COMET INFO:     lr/pg2 [101]                : (0.0001990000000000001, 0.009800693066666666)
# COMET INFO:     metrics/accuracy_top1 [101] : (0.4702, 0.8009)
# COMET INFO:     metrics/accuracy_top5 [101] : (0.9127, 0.9909)
# COMET INFO:     model/GFLOPs                : 3.37
# COMET INFO:     model/parameters            : 1451098
# COMET INFO:     model/speed_PyTorch(ms)     : 0.395
# COMET INFO:     train/loss [100]            : (0.7205, 1.9608)
# COMET INFO:     val/loss [100]              : (1.73869, 2.04849)
# COMET INFO:   Others:
# COMET INFO:     Created from                 : yolov8
# COMET INFO:     eval_batch_logging_interval  : 1
# COMET INFO:     log_confusion_matrix_on_eval : False
# COMET INFO:     log_image_predictions        : True
# COMET INFO:     max_image_predictions        : 100
# COMET INFO:   Parameters:
# COMET INFO:     agnostic_nms    : False
# COMET INFO:     amp             : True
# COMET INFO:     augment         : False
# COMET INFO:     auto_augment    : randaugment
# COMET INFO:     batch           : 16
# COMET INFO:     bgr             : 0.0
# COMET INFO:     box             : 7.5
# COMET INFO:     cache           : False
# COMET INFO:     cfg             : None
# COMET INFO:     classes         : None
# COMET INFO:     close_mosaic    : 10
# COMET INFO:     cls             : 0.5
# COMET INFO:     conf            : None
# COMET INFO:     copy_paste      : 0.0
# COMET INFO:     cos_lr          : False
# COMET INFO:     crop_fraction   : 1.0
# COMET INFO:     data            : C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar
# COMET INFO:     degrees         : 0.0
# COMET INFO:     deterministic   : True
# COMET INFO:     device          : None
# COMET INFO:     dfl             : 1.5
# COMET INFO:     dnn             : False
# COMET INFO:     dropout         : 0.0
# COMET INFO:     dynamic         : False
# COMET INFO:     embed           : None
# COMET INFO:     epochs          : 100
# COMET INFO:     erasing         : 0.4
# COMET INFO:     exist_ok        : False
# COMET INFO:     fliplr          : 0.5
# COMET INFO:     flipud          : 0.0
# COMET INFO:     format          : torchscript
# COMET INFO:     fraction        : 1.0
# COMET INFO:     freeze          : None
# COMET INFO:     half            : False
# COMET INFO:     hsv_h           : 0.015
# COMET INFO:     hsv_s           : 0.7
# COMET INFO:     hsv_v           : 0.4
# COMET INFO:     imgsz           : 32
# COMET INFO:     int8            : False
# COMET INFO:     iou             : 0.7
# COMET INFO:     keras           : False
# COMET INFO:     kobj            : 1.0
# COMET INFO:     label_smoothing : 0.0
# COMET INFO:     line_width      : None
# COMET INFO:     lr0             : 0.01
# COMET INFO:     lrf             : 0.01
# COMET INFO:     mask_ratio      : 4
# COMET INFO:     max_det         : 300
# COMET INFO:     mixup           : 0.0
# COMET INFO:     mode            : train
# COMET INFO:     model           : yolov8n-cls.pt
# COMET INFO:     momentum        : 0.937
# COMET INFO:     mosaic          : 1.0
# COMET INFO:     multi_scale     : False
# COMET INFO:     name            : train
# COMET INFO:     nbs             : 64
# COMET INFO:     nms             : False
# COMET INFO:     opset           : None
# COMET INFO:     optimize        : False
# COMET INFO:     optimizer       : auto
# COMET INFO:     overlap_mask    : True
# COMET INFO:     patience        : 100
# COMET INFO:     perspective     : 0.0
# COMET INFO:     plots           : True
# COMET INFO:     pose            : 12.0
# COMET INFO:     pretrained      : True
# COMET INFO:     profile         : False
# COMET INFO:     project         : None
# COMET INFO:     rect            : False
# COMET INFO:     resume          : False
# COMET INFO:     retina_masks    : False
# COMET INFO:     save            : True
# COMET INFO:     save_conf       : False
# COMET INFO:     save_crop       : False
# COMET INFO:     save_dir        : runs\classify\train
# COMET INFO:     save_frames     : False
# COMET INFO:     save_hybrid     : False
# COMET INFO:     save_json       : False
# COMET INFO:     save_period     : -1
# COMET INFO:     save_txt        : False
# COMET INFO:     scale           : 0.5
# COMET INFO:     seed            : 0
# COMET INFO:     shear           : 0.0
# COMET INFO:     show            : False
# COMET INFO:     show_boxes      : True
# COMET INFO:     show_conf       : True
# COMET INFO:     show_labels     : True
# COMET INFO:     simplify        : False
# COMET INFO:     single_cls      : False
# COMET INFO:     source          : None
# COMET INFO:     split           : val
# COMET INFO:     stream_buffer   : False
# COMET INFO:     task            : classify
# COMET INFO:     time            : None
# COMET INFO:     tracker         : botsort.yaml
# COMET INFO:     translate       : 0.1
# COMET INFO:     val             : True
# COMET INFO:     verbose         : True
# COMET INFO:     vid_stride      : 1
# COMET INFO:     visualize       : False
# COMET INFO:     warmup_bias_lr  : 0.1
# COMET INFO:     warmup_epochs   : 3.0
# COMET INFO:     warmup_momentum : 0.8
# COMET INFO:     weight_decay    : 0.0005
# COMET INFO:     workers         : 8
# COMET INFO:     workspace       : 4
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     confusion-matrix             : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     images                       : 4
# COMET INFO:     installed packages           : 1
# COMET INFO:     model-element                : 1 (2.85 MB)
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET INFO: Please wait for metadata to finish uploading (timeout is 3600 seconds)
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Please wait for assets to finish uploading (timeout is 10800 seconds)
# COMET INFO: Still uploading 1 file(s), remaining 840.01 KB/2.85 MB
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x00000265D0DC6900>
# curves: []
# curves_results: []
# fitness: 0.8950999975204468
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.8007000088691711, 'metrics/accuracy_top5': 0.9894999861717224, 'fitness': 0.8950999975204468}
# save_dir: WindowsPath('runs/classify/train')
# speed: {'preprocess': 0.026129484176635742, 'inference': 0.17275869846343994, 'loss': 0.00039651393890380857, 'postprocess': 0.00047707557678222656}
# task: 'classify'
# top1: 0.8007000088691711
# top5: 0.9894999861717224

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

# Ruta del directorio donde se encuentran las imágenes
directory = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train'

# Listar todos los archivos en el directorio
files = os.listdir(directory)
print("Estos son los archivos de resultado de entrenamiento", files)

# Filtrar solo los archivos de imagen (extensiones comunes)
image_files = [file for file in files if file.endswith(('.png', '.jpg', '.jpeg'))]

# Mostrar todas las imágenes
# Mostrar todas las imágenes
if image_files:
    for image_file in image_files:
        image_path = os.path.join(directory, image_file)

        # Cargar la imagen
        image = Image.open(image_path)

        # Mostrar la imagen
        plt.figure()
        plt.imshow(image)
        plt.axis('off')  # Ocultar los ejes
        plt.title(image_file)  # Título con el nombre del archivo
    plt.show()
else:
    print("No se encontraron imágenes en la carpeta.")
# Out:
# Estos son los archivos de resultado de entrenamiento ['args.yaml', 'confusion_matrix.png', 'confusion_matrix_normalized.png', 'results.csv', 'results.png', 'train_batch0.jpg', 'train_batch1.jpg', 'train_batch2.jpg', 'train_batch225000.jpg', 'train_batch225001.jpg', 'train_batch225002.jpg', 'val_batch0_labels.jpg', 'val_batch0_pred.jpg', 'val_batch1_labels.jpg', 'val_batch1_pred.jpg', 'val_batch2_labels.jpg', 'val_batch2_pred.jpg', 'weights']

# %%
#Predicción con imagen del dataset
import os
from PIL import Image

directory = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\train\frog'

# Si la carpeta tiene imágenes, carga la primera imagen
image_path = os.path.join(directory, os.listdir(directory)[0])
image = Image.open(image_path)

# Realizar la predicción con el modelo YOLO
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones
image.show()
# Out:
# 0: 32x32 frog 0.94, cat 0.03, dog 0.01, bird 0.01, deer 0.01, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict6

# %%
# 10. Predicción con imagen de internet
import os
from PIL import Image

directory = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\rana.jpg'

image = Image.open(directory)

# Realizar la predicción con el modelo YOLO
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones
image.show()
# Out:
# 0: 32x32 frog 0.97, bird 0.01, deer 0.00, cat 0.00, airplane 0.00, 6.1ms
# Speed: 11.1ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict6

# %%
import os
from PIL import Image

directory = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\cauto_test.jpg'

image = Image.open(directory)

# Realizar la predicción con el modelo YOLO
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones
image.show()
# Out:
# 0: 32x32 automobile 0.96, truck 0.02, ship 0.01, airplane 0.01, frog 0.00, 6.5ms
# Speed: 5.5ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict6

# %%
import os
from PIL import Image

directory = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Pelusa.jpeg'

image = Image.open(directory)

# Realizar la predicción con el modelo YOLO
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones
image.show()
# Out:
# 0: 32x32 horse 0.58, cat 0.25, dog 0.07, airplane 0.03, truck 0.03, 6.0ms
# Speed: 11.1ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict6

# %%
import os
from PIL import Image

directory = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\gato3.JPG'

image = Image.open(directory)

# Realizar la predicción con el modelo YOLO
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones
image.show()
# Out:
# 0: 32x32 cat 0.71, dog 0.21, bird 0.02, ship 0.02, truck 0.01, 4.0ms
# Speed: 6.6ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict6

# %%
import os
from PIL import Image

directory = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Minicky.JPEG'

image = Image.open(directory)

# Realizar la predicción con el modelo YOLO
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones
image.show()
# Out:
# 0: 32x32 cat 0.49, bird 0.24, ship 0.11, frog 0.06, airplane 0.05, 5.1ms
# Speed: 11.4ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict6

# %%
import os
from PIL import Image

directory = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Pelusa_zoom.png'

image = Image.open(directory)

# Realizar la predicción con el modelo YOLO
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones
image.show()
# Out:
# 0: 32x32 cat 0.63, ship 0.14, frog 0.12, truck 0.03, dog 0.02, 4.1ms
# Speed: 6.0ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict6

# %%
# 11. Validar el modelo
from ultralytics import YOLO

# Cargar el modelo
model = YOLO(r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.pt')

# Validar el modelo
metrics = model.val()

# Acceder a las métricas de clasificación
print(f"Top-1 Accuracy: {metrics.top1}")
print(f"Top-5 Accuracy: {metrics.top5}")
print(f"Fitness: {metrics.fitness}")

# Si quieres ver todas las métricas disponibles
print("\nTodas las métricas:")
for key, value in metrics.results_dict.items():
    print(f"{key}: {value}")
# Out:
# Ultralytics YOLOv8.2.77  Python-3.12.6 torch-2.4.0 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1,447,690 parameters, 0 gradients, 3.3 GFLOPs
# train: C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\dataset_sin_ordenar\train... found 40000 images in 10 classes
# val: C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\dataset_sin_ordenar\val... found 10000 images in 10 classes
# test: None...
# val: Scanning C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\dataset_sin_ordenar\val... 10000 images, 0 corrupt: 100%|██████████| 10000/10000 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 625/625 [00:05<00:00, 116.83it/s]
#                    all      0.801      0.989
# Speed: 0.0ms preprocess, 0.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs\classify\val2
# Top-1 Accuracy: 0.8009999990463257
# Top-5 Accuracy: 0.9894000291824341
# Fitness: 0.8952000141143799
#
# Todas las métricas:
# metrics/accuracy_top1: 0.8009999990463257
# metrics/accuracy_top5: 0.9894000291824341
# fitness: 0.8952000141143799

# %%
import os
from PIL import Image
from ultralytics import YOLO  # Asegúrate de importar YOLO si no lo has hecho ya

# Ruta del modelo YOLO
model_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.pt'

# Cargar el modelo YOLO
model = YOLO(model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Pelusa.jpeg'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Realizar la predicción con el modelo YOLO usando predict() y un umbral de confianza de 0.25
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones (si se ha guardado o procesado)
image.show()

# Procesar y mostrar los resultados de la predicción
for result in results:
    names = result.names  # Nombres de las clases
    top_class = result.probs.top1  # Índice de la clase con mayor probabilidad
    top_confidence = result.probs.top1conf.item()  # Probabilidad de la clase con mayor probabilidad

    print(f"Clase: {names[top_class]}, Confianza: {top_confidence:.2f}")

    # Si quieres mostrar todas las probabilidades:
    for i, prob in enumerate(result.probs.data):
        print(f"{names[i]}: {prob:.4f}")
# Out:
# 0: 32x32 horse 0.58, cat 0.25, dog 0.07, airplane 0.03, truck 0.03, 4.0ms
# Speed: 10.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict7
# Clase: horse, Confianza: 0.58
# airplane: 0.0255
# automobile: 0.0127
# bird: 0.0094
# cat: 0.2534
# deer: 0.0121
# dog: 0.0658
# frog: 0.0014
# horse: 0.5849
# ship: 0.0098
# truck: 0.0251

# %%
import os
from PIL import Image
from ultralytics import YOLO  # Asegúrate de importar YOLO si no lo has hecho ya

# Ruta del modelo YOLO
model_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.pt'

# Cargar el modelo YOLO
model = YOLO(model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Pelusa_zoom.png'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Realizar la predicción con el modelo YOLO usando predict() y un umbral de confianza de 0.25
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones (si se ha guardado o procesado)
image.show()

# Procesar y mostrar los resultados de la predicción
for result in results:
    names = result.names  # Nombres de las clases
    top_class = result.probs.top1  # Índice de la clase con mayor probabilidad
    top_confidence = result.probs.top1conf.item()  # Probabilidad de la clase con mayor probabilidad

    print(f"Clase: {names[top_class]}, Confianza: {top_confidence:.2f}")

    # Si quieres mostrar todas las probabilidades:
    for i, prob in enumerate(result.probs.data):
        print(f"{names[i]}: {prob:.4f}")
# Out:
# 0: 32x32 cat 0.63, ship 0.14, frog 0.12, truck 0.03, dog 0.02, 4.5ms
# Speed: 5.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict8
# Clase: cat, Confianza: 0.63
# airplane: 0.0066
# automobile: 0.0173
# bird: 0.0169
# cat: 0.6332
# deer: 0.0053
# dog: 0.0192
# frog: 0.1200
# horse: 0.0112
# ship: 0.1407
# truck: 0.0296

# %%
import os
from PIL import Image
from ultralytics import YOLO  # Asegúrate de importar YOLO si no lo has hecho ya

# Ruta del modelo YOLO
model_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.pt'

# Cargar el modelo YOLO
model = YOLO(model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\cauto_test.jpg'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Realizar la predicción con el modelo YOLO usando predict() y un umbral de confianza de 0.25
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones (si se ha guardado o procesado)
image.show()

# Procesar y mostrar los resultados de la predicción
for result in results:
    names = result.names  # Nombres de las clases
    top_class = result.probs.top1  # Índice de la clase con mayor probabilidad
    top_confidence = result.probs.top1conf.item()  # Probabilidad de la clase con mayor probabilidad

    print(f"Clase: {names[top_class]}, Confianza: {top_confidence:.2f}")

    # Si quieres mostrar todas las probabilidades:
    for i, prob in enumerate(result.probs.data):
        print(f"{names[i]}: {prob:.4f}")
# Out:
# 0: 32x32 automobile 0.96, truck 0.02, ship 0.01, airplane 0.01, frog 0.00, 4.6ms
# Speed: 5.0ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict5
# Clase: automobile, Confianza: 0.96
# airplane: 0.0063
# automobile: 0.9605
# bird: 0.0005
# cat: 0.0008
# deer: 0.0002
# dog: 0.0002
# frog: 0.0014
# horse: 0.0001
# ship: 0.0111
# truck: 0.0190

# %%
import os
from PIL import Image
from ultralytics import YOLO  # Asegúrate de importar YOLO si no lo has hecho ya

# Ruta del modelo YOLO
model_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.pt'

# Cargar el modelo YOLO
model = YOLO(model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\rana.jpg'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Realizar la predicción con el modelo YOLO usando predict() y un umbral de confianza de 0.25
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones (si se ha guardado o procesado)
image.show()

# Procesar y mostrar los resultados de la predicción
for result in results:
    names = result.names  # Nombres de las clases
    top_class = result.probs.top1  # Índice de la clase con mayor probabilidad
    top_confidence = result.probs.top1conf.item()  # Probabilidad de la clase con mayor probabilidad

    print(f"Clase: {names[top_class]}, Confianza: {top_confidence:.2f}")

    # Si quieres mostrar todas las probabilidades:
    for i, prob in enumerate(result.probs.data):
        print(f"{names[i]}: {prob:.4f}")
# Out:
# 0: 32x32 frog 0.97, bird 0.01, deer 0.00, cat 0.00, airplane 0.00, 5.4ms
# Speed: 17.8ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict9
# Clase: frog, Confianza: 0.97
# airplane: 0.0012
# automobile: 0.0007
# bird: 0.0132
# cat: 0.0026
# deer: 0.0047
# dog: 0.0010
# frog: 0.9750
# horse: 0.0005
# ship: 0.0005
# truck: 0.0006

# %%
import os
from PIL import Image
from ultralytics import YOLO  # Asegúrate de importar YOLO si no lo has hecho ya

# Ruta del modelo YOLO
model_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.pt'

# Cargar el modelo YOLO
model = YOLO(model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\gato3.JPG'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Realizar la predicción con el modelo YOLO usando predict() y un umbral de confianza de 0.25
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones (si se ha guardado o procesado)
image.show()

# Procesar y mostrar los resultados de la predicción
for result in results:
    names = result.names  # Nombres de las clases
    top_class = result.probs.top1  # Índice de la clase con mayor probabilidad
    top_confidence = result.probs.top1conf.item()  # Probabilidad de la clase con mayor probabilidad

    print(f"Clase: {names[top_class]}, Confianza: {top_confidence:.2f}")

    # Si quieres mostrar todas las probabilidades:
    for i, prob in enumerate(result.probs.data):
        print(f"{names[i]}: {prob:.4f}")
# Out:
# 0: 32x32 cat 0.71, dog 0.21, bird 0.02, ship 0.02, truck 0.01, 4.5ms
# Speed: 6.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict10
# Clase: cat, Confianza: 0.71
# airplane: 0.0016
# automobile: 0.0014
# bird: 0.0172
# cat: 0.7128
# deer: 0.0081
# dog: 0.2068
# frog: 0.0126
# horse: 0.0107
# ship: 0.0158
# truck: 0.0131

# %%
import os
from PIL import Image
from ultralytics import YOLO  # Asegúrate de importar YOLO si no lo has hecho ya

# Ruta del modelo YOLO
model_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.pt'

# Cargar el modelo YOLO
model = YOLO(model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Minicky.JPEG'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Realizar la predicción con el modelo YOLO usando predict() y un umbral de confianza de 0.25
results = model.predict(image, conf=0.25, save=True)

# Mostrar la imagen con las predicciones (si se ha guardado o procesado)
image.show()

# Procesar y mostrar los resultados de la predicción
for result in results:
    names = result.names  # Nombres de las clases
    top_class = result.probs.top1  # Índice de la clase con mayor probabilidad
    top_confidence = result.probs.top1conf.item()  # Probabilidad de la clase con mayor probabilidad

    print(f"Clase: {names[top_class]}, Confianza: {top_confidence:.2f}")

    # Si quieres mostrar todas las probabilidades:
    for i, prob in enumerate(result.probs.data):
        print(f"{names[i]}: {prob:.4f}")
# Out:
# 0: 32x32 cat 0.49, bird 0.24, ship 0.11, frog 0.06, airplane 0.05, 6.5ms
# Speed: 17.1ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 32, 32)
# Results saved to runs\classify\predict11
# Clase: cat, Confianza: 0.49
# airplane: 0.0500
# automobile: 0.0079
# bird: 0.2441
# cat: 0.4904
# deer: 0.0125
# dog: 0.0128
# frog: 0.0585
# horse: 0.0067
# ship: 0.1127
# truck: 0.0044

# %%
# 14. Exportar modelo a onnx
from ultralytics import YOLO

model = YOLO(r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.pt')  # load a custom trained model

# Export the model
model.export(format='onnx', opset=12, simplify=True)
# Out:
# Ultralytics YOLOv8.2.77  Python-3.12.6 torch-2.4.0 CPU (11th Gen Intel Core(TM) i7-11800H 2.30GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1,447,690 parameters, 0 gradients, 3.3 GFLOPs
#
# PyTorch: starting from 'C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\runs\classify\train\weights\best.pt' with input shape (1, 3, 32, 32) BCHW and output shape(s) (1, 10) (2.9 MB)
# requirements: Ultralytics requirements ['onnxslim>=0.1.31', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Retry 1/2 failed: Command 'pip install --no-cache-dir "onnxslim>=0.1.31" "onnxruntime-gpu" ' returned non-zero exit status 1.
# Retry 2/2 failed: Command 'pip install --no-cache-dir "onnxslim>=0.1.31" "onnxruntime-gpu" ' returned non-zero exit status 1.
# requirements:  Command 'pip install --no-cache-dir "onnxslim>=0.1.31" "onnxruntime-gpu" ' returned non-zero exit status 1.
#
# ONNX: starting export with onnx 1.16.2 opset 12...
# ONNX: slimming with onnxslim 0.1.34...
# ONNX: export success  251.4s, saved as 'C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\runs\classify\train\weights\best.onnx' (5.5 MB)
#
# Export complete (253.4s)
# Results saved to C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\runs\classify\train\weights
# Predict:         yolo predict task=classify model=C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\runs\classify\train\weights\best.onnx imgsz=32
# Validate:        yolo val task=classify model=C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\runs\classify\train\weights\best.onnx imgsz=32 data=C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\dataset_sin_ordenar
# Visualize:       https://netron.app
# 'C:\\Users\\User\\Documents\\JUPYTER_LOCAL\\IMÁGENES_ENTRENAMIENTO\\CLASIFICACIÓN\\CIFAR_KAGGLE\\runs\\classify\\train\\weights\\best.onnx'

# %%
import onnxruntime as ort
from PIL import Image
import numpy as np
import os

# Ruta del modelo ONNX exportado
onnx_model_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.onnx'

# Cargar el modelo ONNX usando onnxruntime
session = ort.InferenceSession(onnx_model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\cauto_test.jpg'  # Cambia esto a la ruta real de tu imagen

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Redimensionar la imagen al tamaño adecuado para CIFAR-10 (32x32)
image = image.resize((32, 32))

# Convertir la imagen a un array numpy y escalar los valores de píxeles
image_np = np.array(image).astype(np.float32) / 255.0

# Cambiar el formato de la imagen a (1, 3, 32, 32) -> (batch_size, canales, alto, ancho)
image_np = np.transpose(image_np, (2, 0, 1))  # Cambiar los ejes para que esté en formato canales primero
image_np = np.expand_dims(image_np, axis=0)   # Añadir la dimensión de batch_size

# Realizar la predicción con el modelo ONNX
input_name = session.get_inputs()[0].name  # Obtener el nombre del primer input del modelo
output_name = session.get_outputs()[0].name  # Obtener el nombre del primer output del modelo
results = session.run([output_name], {input_name: image_np})

# Procesar los resultados de la predicción
predicciones = results[0][0]  # Acceder a las predicciones de la primera imagen
clase_detectada = np.argmax(predicciones)  # Obtener la clase con mayor probabilidad
probabilidad = np.max(predicciones)

# Nombres de las clases del CIFAR-10
clases = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Mostrar la primera opción detectada
print(f"Primera opción detectada: {clases[clase_detectada]} con probabilidad {probabilidad:.2f}")

# Si quieres ver todas las probabilidades
for i, prob in enumerate(predicciones):
    print(f"{clases[i]}: {prob:.4f}")
# Out:
# Primera opción detectada: airplane con probabilidad 0.30
# airplane: 0.2982
# automobile: 0.2795
# bird: 0.0072
# cat: 0.0057
# deer: 0.0066
# dog: 0.0017
# frog: 0.0220
# horse: 0.0017
# ship: 0.2077
# truck: 0.1697

# %%
import onnxruntime as ort
from PIL import Image
import numpy as np
import os

# Ruta del modelo ONNX exportado
onnx_model_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.onnx'

# Cargar el modelo ONNX usando onnxruntime
session = ort.InferenceSession(onnx_model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\rana.jpg'  # Cambia esto a la ruta real de tu imagen

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Redimensionar la imagen al tamaño adecuado para CIFAR-10 (32x32)
image = image.resize((32, 32))

# Convertir la imagen a un array numpy y escalar los valores de píxeles
image_np = np.array(image).astype(np.float32) / 255.0

# Cambiar el formato de la imagen a (1, 3, 32, 32) -> (batch_size, canales, alto, ancho)
image_np = np.transpose(image_np, (2, 0, 1))  # Cambiar los ejes para que esté en formato canales primero
image_np = np.expand_dims(image_np, axis=0)   # Añadir la dimensión de batch_size

# Realizar la predicción con el modelo ONNX
input_name = session.get_inputs()[0].name  # Obtener el nombre del primer input del modelo
output_name = session.get_outputs()[0].name  # Obtener el nombre del primer output del modelo
results = session.run([output_name], {input_name: image_np})

# Procesar los resultados de la predicción
predicciones = results[0][0]  # Acceder a las predicciones de la primera imagen
clase_detectada = np.argmax(predicciones)  # Obtener la clase con mayor probabilidad
probabilidad = np.max(predicciones)

# Nombres de las clases del CIFAR-10
clases = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Mostrar la primera opción detectada
print(f"Primera opción detectada: {clases[clase_detectada]} con probabilidad {probabilidad:.2f}")

# Si quieres ver todas las probabilidades
for i, prob in enumerate(predicciones):
    print(f"{clases[i]}: {prob:.4f}")
# Out:
# Primera opción detectada: frog con probabilidad 0.87
# airplane: 0.0038
# automobile: 0.0005
# bird: 0.0888
# cat: 0.0076
# deer: 0.0235
# dog: 0.0033
# frog: 0.8681
# horse: 0.0027
# ship: 0.0004
# truck: 0.0013

# %%
import onnxruntime as ort
from PIL import Image
import numpy as np
import os

# Ruta del modelo ONNX exportado
onnx_model_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.onnx'

# Cargar el modelo ONNX usando onnxruntime
session = ort.InferenceSession(onnx_model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Pelusa.JPEG'  # Cambia esto a la ruta real de tu imagen

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Redimensionar la imagen al tamaño adecuado para CIFAR-10 (32x32)
image = image.resize((32, 32))

# Convertir la imagen a un array numpy y escalar los valores de píxeles
image_np = np.array(image).astype(np.float32) / 255.0

# Cambiar el formato de la imagen a (1, 3, 32, 32) -> (batch_size, canales, alto, ancho)
image_np = np.transpose(image_np, (2, 0, 1))  # Cambiar los ejes para que esté en formato canales primero
image_np = np.expand_dims(image_np, axis=0)   # Añadir la dimensión de batch_size

# Realizar la predicción con el modelo ONNX
input_name = session.get_inputs()[0].name  # Obtener el nombre del primer input del modelo
output_name = session.get_outputs()[0].name  # Obtener el nombre del primer output del modelo
results = session.run([output_name], {input_name: image_np})

# Procesar los resultados de la predicción
predicciones = results[0][0]  # Acceder a las predicciones de la primera imagen
clase_detectada = np.argmax(predicciones)  # Obtener la clase con mayor probabilidad
probabilidad = np.max(predicciones)

# Nombres de las clases del CIFAR-10
clases = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Mostrar la primera opción detectada
print(f"Primera opción detectada: {clases[clase_detectada]} con probabilidad {probabilidad:.2f}")

# Si quieres ver todas las probabilidades
for i, prob in enumerate(predicciones):
    print(f"{clases[i]}: {prob:.4f}")
# Out:
# Primera opción detectada: airplane con probabilidad 0.40
# airplane: 0.4043
# automobile: 0.0395
# bird: 0.0085
# cat: 0.0969
# deer: 0.0117
# dog: 0.0214
# frog: 0.0019
# horse: 0.2666
# ship: 0.0282
# truck: 0.1211

# %%
import onnxruntime as ort
from PIL import Image
import numpy as np
import os

# Ruta del modelo ONNX exportado
onnx_model_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.onnx'

# Cargar el modelo ONNX usando onnxruntime
session = ort.InferenceSession(onnx_model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Pelusa_zoom.png'  # Cambia esto a la ruta real de tu imagen

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Redimensionar la imagen al tamaño adecuado para CIFAR-10 (32x32)
image = image.resize((32, 32))

# Convertir la imagen a un array numpy y escalar los valores de píxeles
image_np = np.array(image).astype(np.float32) / 255.0

# Cambiar el formato de la imagen a (1, 3, 32, 32) -> (batch_size, canales, alto, ancho)
image_np = np.transpose(image_np, (2, 0, 1))  # Cambiar los ejes para que esté en formato canales primero
image_np = np.expand_dims(image_np, axis=0)   # Añadir la dimensión de batch_size

# Realizar la predicción con el modelo ONNX
input_name = session.get_inputs()[0].name  # Obtener el nombre del primer input del modelo
output_name = session.get_outputs()[0].name  # Obtener el nombre del primer output del modelo
results = session.run([output_name], {input_name: image_np})

# Procesar los resultados de la predicción
predicciones = results[0][0]  # Acceder a las predicciones de la primera imagen
clase_detectada = np.argmax(predicciones)  # Obtener la clase con mayor probabilidad
probabilidad = np.max(predicciones)

# Nombres de las clases del CIFAR-10
clases = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Mostrar la primera opción detectada
print(f"Primera opción detectada: {clases[clase_detectada]} con probabilidad {probabilidad:.2f}")

# Si quieres ver todas las probabilidades
for i, prob in enumerate(predicciones):
    print(f"{clases[i]}: {prob:.4f}")
# Out:
# Primera opción detectada: cat con probabilidad 0.64
# airplane: 0.0053
# automobile: 0.0124
# bird: 0.0163
# cat: 0.6418
# deer: 0.0066
# dog: 0.0316
# frog: 0.1658
# horse: 0.0137
# ship: 0.0864
# truck: 0.0202

# %%
import onnxruntime as ort
from PIL import Image
import numpy as np
import os

# Ruta del modelo ONNX exportado
onnx_model_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\runs\classify\train\weights\best.onnx'

# Cargar el modelo ONNX usando onnxruntime
session = ort.InferenceSession(onnx_model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Minicky.JPEG'  # Cambia esto a la ruta real de tu imagen

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Redimensionar la imagen al tamaño adecuado para CIFAR-10 (32x32)
image = image.resize((32, 32))

# Convertir la imagen a un array numpy y escalar los valores de píxeles
image_np = np.array(image).astype(np.float32) / 255.0

# Cambiar el formato de la imagen a (1, 3, 32, 32) -> (batch_size, canales, alto, ancho)
image_np = np.transpose(image_np, (2, 0, 1))  # Cambiar los ejes para que esté en formato canales primero
image_np = np.expand_dims(image_np, axis=0)   # Añadir la dimensión de batch_size

# Realizar la predicción con el modelo ONNX
input_name = session.get_inputs()[0].name  # Obtener el nombre del primer input del modelo
output_name = session.get_outputs()[0].name  # Obtener el nombre del primer output del modelo
results = session.run([output_name], {input_name: image_np})

# Procesar los resultados de la predicción
predicciones = results[0][0]  # Acceder a las predicciones de la primera imagen
clase_detectada = np.argmax(predicciones)  # Obtener la clase con mayor probabilidad
probabilidad = np.max(predicciones)

# Nombres de las clases del CIFAR-10
clases = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Mostrar la primera opción detectada
print(f"Primera opción detectada: {clases[clase_detectada]} con probabilidad {probabilidad:.2f}")

# Si quieres ver todas las probabilidades
for i, prob in enumerate(predicciones):
    print(f"{clases[i]}: {prob:.4f}")
# Out:
# Primera opción detectada: cat con probabilidad 0.35
# airplane: 0.0305
# automobile: 0.0020
# bird: 0.2840
# cat: 0.3481
# deer: 0.0340
# dog: 0.0072
# frog: 0.2690
# horse: 0.0028
# ship: 0.0218
# truck: 0.0005

# %%
# Crear modelo en TorchScript

model = YOLO(r'best.pt')  # load a custom trained model

# Export the model
model.export(format='torchscript', opset=12, simplify=True)
# Out:
# Ultralytics YOLOv8.2.77  Python-3.12.6 torch-2.4.0 CPU (11th Gen Intel Core(TM) i7-11800H 2.30GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1,447,690 parameters, 0 gradients, 3.3 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 32, 32) BCHW and output shape(s) (1, 10) (2.9 MB)
#
# TorchScript: starting export with torch 2.4.0...
# TorchScript: export success  0.8s, saved as 'best.torchscript' (5.7 MB)
#
# Export complete (2.5s)
# Results saved to C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE
# Predict:         yolo predict task=classify model=best.torchscript imgsz=32
# Validate:        yolo val task=classify model=best.torchscript imgsz=32 data=C:\Users\User\Documents\JUPYTER_LOCAL\IMGENES_ENTRENAMIENTO\CLASIFICACIN\CIFAR_KAGGLE\dataset_sin_ordenar
# Visualize:       https://netron.app
# 'best.torchscript'

# %%
# Load the YOLOv8 model
model = YOLO("yolov8n.pt")

# Export the model to TorchScript format
model.export(format="torchscript")  # creates 'yolov8n.torchscript'

# %%
import torch
from PIL import Image
import numpy as np
import torchvision.transforms as transforms

# Cargar el modelo TorchScript
torchscript_model_path = r'best.torchscript'
torchscript_model = torch.jit.load(torchscript_model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Minicky.JPEG'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB, y convertir si es necesario
if image.mode != 'RGB':
    image = image.convert('RGB')

# Preprocesar la imagen: redimensionar, convertir a tensor y normalizar
transform = transforms.Compose([
    transforms.Resize((32, 32)),  # Redimensionar al tamaño requerido (CIFAR-10 usa 32x32)
    transforms.ToTensor(),        # Convertir la imagen a un tensor
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalización (esto depende de cómo se entrenó tu modelo)
])

# Aplicar las transformaciones a la imagen
image_tensor = transform(image)

# Añadir una dimensión adicional para representar el batch (batch_size=1)
image_tensor = image_tensor.unsqueeze(0)

# Pasar la imagen a través del modelo TorchScript
with torch.no_grad():  # Desactiva el cálculo de gradientes para la inferencia
    results = torchscript_model(image_tensor)

# Verificar la forma del tensor de predicciones
print(f"Forma de las predicciones: {results.shape}")

# Acceder a las predicciones de la primera imagen (ajusta según la forma del tensor)
predicciones = results[0].numpy() if results.dim() > 1 else results.numpy()

# Verificar si las predicciones tienen el formato correcto
print(f"Predicciones (primera imagen): {predicciones}")

# Obtener la clase con mayor probabilidad
clase_detectada = np.argmax(predicciones)
probabilidad = np.max(predicciones)

# Nombres de las clases del CIFAR-10
clases = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Mostrar la primera opción detectada
print(f"Primera opción detectada: {clases[clase_detectada]} con probabilidad {probabilidad:.2f}")

# Si quieres ver todas las probabilidades
for i, prob in enumerate(predicciones):
    print(f"{clases[i]}: {prob:.4f}")
# Out:
# Forma de las predicciones: torch.Size([1, 10])
# Predicciones (primera imagen): [   0.070345   0.0074497      0.0601     0.63783    0.052219     0.13426    0.019302   0.0099689   0.0063908   0.0021258]
# Primera opción detectada: cat con probabilidad 0.64
# airplane: 0.0703
# automobile: 0.0074
# bird: 0.0601
# cat: 0.6378
# deer: 0.0522
# dog: 0.1343
# frog: 0.0193
# horse: 0.0100
# ship: 0.0064
# truck: 0.0021

# %%
import torch
from PIL import Image
import numpy as np
import torchvision.transforms as transforms

# Cargar el modelo TorchScript
torchscript_model_path = r'best.torchscript'
torchscript_model = torch.jit.load(torchscript_model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\rana.jpg'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB, y convertir si es necesario
if image.mode != 'RGB':
    image = image.convert('RGB')

# Preprocesar la imagen: redimensionar, convertir a tensor y normalizar
transform = transforms.Compose([
    transforms.Resize((32, 32)),  # Redimensionar al tamaño requerido (CIFAR-10 usa 32x32)
    transforms.ToTensor(),        # Convertir la imagen a un tensor
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalización (esto depende de cómo se entrenó tu modelo)
])

# Aplicar las transformaciones a la imagen
image_tensor = transform(image)

# Añadir una dimensión adicional para representar el batch (batch_size=1)
image_tensor = image_tensor.unsqueeze(0)

# Pasar la imagen a través del modelo TorchScript
with torch.no_grad():  # Desactiva el cálculo de gradientes para la inferencia
    results = torchscript_model(image_tensor)

# Verificar la forma del tensor de predicciones
print(f"Forma de las predicciones: {results.shape}")

# Acceder a las predicciones de la primera imagen (ajusta según la forma del tensor)
predicciones = results[0].numpy() if results.dim() > 1 else results.numpy()

# Verificar si las predicciones tienen el formato correcto
print(f"Predicciones (primera imagen): {predicciones}")

# Obtener la clase con mayor probabilidad
clase_detectada = np.argmax(predicciones)
probabilidad = np.max(predicciones)

# Nombres de las clases del CIFAR-10
clases = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Mostrar la primera opción detectada
print(f"Primera opción detectada: {clases[clase_detectada]} con probabilidad {probabilidad:.2f}")

# Si quieres ver todas las probabilidades
for i, prob in enumerate(predicciones):
    print(f"{clases[i]}: {prob:.4f}")
# Out:
# Forma de las predicciones: torch.Size([1, 10])
# Predicciones (primera imagen): [   0.072716    0.016098    0.065377     0.22074    0.016151     0.54332   0.0042515    0.039574   0.0012607    0.020514]
# Primera opción detectada: dog con probabilidad 0.54
# airplane: 0.0727
# automobile: 0.0161
# bird: 0.0654
# cat: 0.2207
# deer: 0.0162
# dog: 0.5433
# frog: 0.0043
# horse: 0.0396
# ship: 0.0013
# truck: 0.0205

# %%
import torch
from PIL import Image
import numpy as np
import torchvision.transforms as transforms

# Cargar el modelo TorchScript
torchscript_model_path = r'best.torchscript'
torchscript_model = torch.jit.load(torchscript_model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\cauto_test.jpg'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB, y convertir si es necesario
if image.mode != 'RGB':
    image = image.convert('RGB')

# Preprocesar la imagen: redimensionar, convertir a tensor y normalizar
transform = transforms.Compose([
    transforms.Resize((32, 32)),  # Redimensionar al tamaño requerido (CIFAR-10 usa 32x32)
    transforms.ToTensor(),        # Convertir la imagen a un tensor
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalización (esto depende de cómo se entrenó tu modelo)
])

# Aplicar las transformaciones a la imagen
image_tensor = transform(image)

# Añadir una dimensión adicional para representar el batch (batch_size=1)
image_tensor = image_tensor.unsqueeze(0)

# Pasar la imagen a través del modelo TorchScript
with torch.no_grad():  # Desactiva el cálculo de gradientes para la inferencia
    results = torchscript_model(image_tensor)

# Verificar la forma del tensor de predicciones
print(f"Forma de las predicciones: {results.shape}")

# Acceder a las predicciones de la primera imagen (ajusta según la forma del tensor)
predicciones = results[0].numpy() if results.dim() > 1 else results.numpy()

# Verificar si las predicciones tienen el formato correcto
print(f"Predicciones (primera imagen): {predicciones}")

# Obtener la clase con mayor probabilidad
clase_detectada = np.argmax(predicciones)
probabilidad = np.max(predicciones)

# Nombres de las clases del CIFAR-10
clases = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Mostrar la primera opción detectada
print(f"Primera opción detectada: {clases[clase_detectada]} con probabilidad {probabilidad:.2f}")

# Si quieres ver todas las probabilidades
for i, prob in enumerate(predicciones):
    print(f"{clases[i]}: {prob:.4f}")
# Out:
# Forma de las predicciones: torch.Size([1, 10])
# Predicciones (primera imagen): [    0.22938    0.050702    0.092445     0.21366     0.14999      0.1324    0.029231    0.032863    0.046028    0.023296]
# Primera opción detectada: airplane con probabilidad 0.23
# airplane: 0.2294
# automobile: 0.0507
# bird: 0.0924
# cat: 0.2137
# deer: 0.1500
# dog: 0.1324
# frog: 0.0292
# horse: 0.0329
# ship: 0.0460
# truck: 0.0233

# %%
import torch
from PIL import Image
import numpy as np
import torchvision.transforms as transforms

# Cargar el modelo TorchScript
torchscript_model_path = r'best.torchscript'
torchscript_model = torch.jit.load(torchscript_model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Pelusa.JPEG'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB, y convertir si es necesario
if image.mode != 'RGB':
    image = image.convert('RGB')

# Preprocesar la imagen: redimensionar, convertir a tensor y normalizar
transform = transforms.Compose([
    transforms.Resize((32, 32)),  # Redimensionar al tamaño requerido (CIFAR-10 usa 32x32)
    transforms.ToTensor(),        # Convertir la imagen a un tensor
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalización (esto depende de cómo se entrenó tu modelo)
])

# Aplicar las transformaciones a la imagen
image_tensor = transform(image)

# Añadir una dimensión adicional para representar el batch (batch_size=1)
image_tensor = image_tensor.unsqueeze(0)

# Pasar la imagen a través del modelo TorchScript
with torch.no_grad():  # Desactiva el cálculo de gradientes para la inferencia
    results = torchscript_model(image_tensor)

# Verificar la forma del tensor de predicciones
print(f"Forma de las predicciones: {results.shape}")

# Acceder a las predicciones de la primera imagen (ajusta según la forma del tensor)
predicciones = results[0].numpy() if results.dim() > 1 else results.numpy()

# Verificar si las predicciones tienen el formato correcto
print(f"Predicciones (primera imagen): {predicciones}")

# Obtener la clase con mayor probabilidad
clase_detectada = np.argmax(predicciones)
probabilidad = np.max(predicciones)

# Nombres de las clases del CIFAR-10
clases = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Mostrar la primera opción detectada
print(f"Primera opción detectada: {clases[clase_detectada]} con probabilidad {probabilidad:.2f}")

# Si quieres ver todas las probabilidades
for i, prob in enumerate(predicciones):
    print(f"{clases[i]}: {prob:.4f}")
# Out:
# Forma de las predicciones: torch.Size([1, 10])
# Predicciones (primera imagen): [   0.094747   0.0030679     0.10371     0.20438    0.028751     0.44844   0.0045268     0.07846   0.0084368    0.025472]
# Primera opción detectada: dog con probabilidad 0.45
# airplane: 0.0947
# automobile: 0.0031
# bird: 0.1037
# cat: 0.2044
# deer: 0.0288
# dog: 0.4484
# frog: 0.0045
# horse: 0.0785
# ship: 0.0084
# truck: 0.0255

# %%
import torch
from PIL import Image
import numpy as np
import torchvision.transforms as transforms

# Cargar el modelo TorchScript
torchscript_model_path = r'best.torchscript'
torchscript_model = torch.jit.load(torchscript_model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\Pelusa_zoom.png'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB, y convertir si es necesario
if image.mode != 'RGB':
    image = image.convert('RGB')

# Preprocesar la imagen: redimensionar, convertir a tensor y normalizar
transform = transforms.Compose([
    transforms.Resize((32, 32)),  # Redimensionar al tamaño requerido (CIFAR-10 usa 32x32)
    transforms.ToTensor(),        # Convertir la imagen a un tensor
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalización (esto depende de cómo se entrenó tu modelo)
])

# Aplicar las transformaciones a la imagen
image_tensor = transform(image)

# Añadir una dimensión adicional para representar el batch (batch_size=1)
image_tensor = image_tensor.unsqueeze(0)

# Pasar la imagen a través del modelo TorchScript
with torch.no_grad():  # Desactiva el cálculo de gradientes para la inferencia
    results = torchscript_model(image_tensor)

# Verificar la forma del tensor de predicciones
print(f"Forma de las predicciones: {results.shape}")

# Acceder a las predicciones de la primera imagen (ajusta según la forma del tensor)
predicciones = results[0].numpy() if results.dim() > 1 else results.numpy()

# Verificar si las predicciones tienen el formato correcto
print(f"Predicciones (primera imagen): {predicciones}")

# Obtener la clase con mayor probabilidad
clase_detectada = np.argmax(predicciones)
probabilidad = np.max(predicciones)

# Nombres de las clases del CIFAR-10
clases = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Mostrar la primera opción detectada
print(f"Primera opción detectada: {clases[clase_detectada]} con probabilidad {probabilidad:.2f}")

# Si quieres ver todas las probabilidades
for i, prob in enumerate(predicciones):
    print(f"{clases[i]}: {prob:.4f}")
# Out:
# Forma de las predicciones: torch.Size([1, 10])
# Predicciones (primera imagen): [   0.029169   0.0088697    0.050853      0.6844    0.019735     0.05789     0.09648    0.015684   0.0079564    0.028963]
# Primera opción detectada: cat con probabilidad 0.68
# airplane: 0.0292
# automobile: 0.0089
# bird: 0.0509
# cat: 0.6844
# deer: 0.0197
# dog: 0.0579
# frog: 0.0965
# horse: 0.0157
# ship: 0.0080
# truck: 0.0290

# %%
import torch
from PIL import Image
import numpy as np
import torchvision.transforms as transforms

# Cargar el modelo TorchScript
torchscript_model_path = r'best.torchscript'
torchscript_model = torch.jit.load(torchscript_model_path)

# Ruta de la imagen local
image_path = r'C:\Users\User\Documents\JUPYTER_LOCAL\IMÁGENES_ENTRENAMIENTO\CLASIFICACIÓN\CIFAR_KAGGLE\gato3.jpg'

# Cargar la imagen desde el sistema de archivos
image = Image.open(image_path)

# Verificar si la imagen está en RGB, y convertir si es necesario
if image.mode != 'RGB':
    image = image.convert('RGB')

# Preprocesar la imagen: redimensionar, convertir a tensor y normalizar
transform = transforms.Compose([
    transforms.Resize((32, 32)),  # Redimensionar al tamaño requerido (CIFAR-10 usa 32x32)
    transforms.ToTensor(),        # Convertir la imagen a un tensor
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalización (esto depende de cómo se entrenó tu modelo)
])

# Aplicar las transformaciones a la imagen
image_tensor = transform(image)

# Añadir una dimensión adicional para representar el batch (batch_size=1)
image_tensor = image_tensor.unsqueeze(0)

# Pasar la imagen a través del modelo TorchScript
with torch.no_grad():  # Desactiva el cálculo de gradientes para la inferencia
    results = torchscript_model(image_tensor)

# Verificar la forma del tensor de predicciones
print(f"Forma de las predicciones: {results.shape}")

# Acceder a las predicciones de la primera imagen (ajusta según la forma del tensor)
predicciones = results[0].numpy() if results.dim() > 1 else results.numpy()

# Verificar si las predicciones tienen el formato correcto
print(f"Predicciones (primera imagen): {predicciones}")

# Obtener la clase con mayor probabilidad
clase_detectada = np.argmax(predicciones)
probabilidad = np.max(predicciones)

# Nombres de las clases del CIFAR-10
clases = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Mostrar la primera opción detectada
print(f"Primera opción detectada: {clases[clase_detectada]} con probabilidad {probabilidad:.2f}")

# Si quieres ver todas las probabilidades
for i, prob in enumerate(predicciones):
    print(f"{clases[i]}: {prob:.4f}")
# Out:
# Forma de las predicciones: torch.Size([1, 10])
# Predicciones (primera imagen): [   0.091238   0.0020337     0.22801     0.34233    0.034457     0.21931   0.0086768     0.04279    0.012179    0.018983]
# Primera opción detectada: cat con probabilidad 0.34
# airplane: 0.0912
# automobile: 0.0020
# bird: 0.2280
# cat: 0.3423
# deer: 0.0345
# dog: 0.2193
# frog: 0.0087
# horse: 0.0428
# ship: 0.0122
# truck: 0.0190
