# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.91 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.8/107.7 GB disk)

# %%
# !wget https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/pose1.jpg
# !wget https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/pose2.jpg
# !wget https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/personas5.jpg
# !wget https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/pose4.jpg
# Out:
# --2024-09-10 00:29:49--  https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/pose1.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4158154 (4.0M) [image/jpeg]
# Saving to: ‘pose1.jpg’
#
# pose1.jpg           100%[===================>]   3.96M  --.-KB/s    in 0.08s
#
# 2024-09-10 00:29:49 (48.2 MB/s) - ‘pose1.jpg’ saved [4158154/4158154]
#
# --2024-09-10 00:29:50--  https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/pose2.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %%
from ultralytics import YOLO
import os
import matplotlib.pyplot as plt
import cv2

model = YOLO('yolov8s-pose.pt')
results = model('pose1.jpg')

save_dir = save_dir = "/content/YOLO-Pre-Trained-Results"
os.makedirs(save_dir, exist_ok=True)

result = results[0]

file_path = os.path.join(save_dir, 'pose1_result.jpg')
result.save(file_path)

# Verificar si la imagen ha sido guardado o no
if os.path.exists(file_path):
    print(f"La imagen se ha guardado en: {file_path}")
else:
    print("No se ha podido guardar la imagen.")
# Out:
# ...
# 100%|██████████| 22.4M/22.4M [00:00<00:00, 168MB/s]
# image 1/1 /content/pose1.jpg: 640x512 1 person, 2296.4ms
# Speed: 16.0ms preprocess, 2296.4ms inference, 23.1ms postprocess per image at shape (1, 3, 640, 512)
# La imagen se ha guardado en: /content/YOLO-Pre-Trained-Results/pose1_result.jpg

# %%
import matplotlib.pyplot as plt
import cv2

resultado_pose = "/content/YOLO-Pre-Trained-Results/pose1_result.jpg"
img = cv2.imread(resultado_pose)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_color)
plt.axis('off')
plt.show()

# %%
from ultralytics import YOLO
import os

model = YOLO('yolov8s-pose.pt')

imagenes = ["pose2.jpg", "personas5.jpg", "pose4.jpg"]

save_dir = "/content/YOLO-Pre-Trained-Results"
os.makedirs(save_dir, exist_ok=True)

for imagen in imagenes:
    results = model(imagen)
    result = results[0]
    output_image_name = f'Resultado_{os.path.basename(imagen)}'
    output_image_path = os.path.join(save_dir, output_image_name)
    result.save(output_image_path)

    # Verificar si los resultados fueron guardados
if os.path.exists(file_path):
  print(f"Imagen guardada correctamente en {file_path}")
else:
  print("No se pudo guardar la imagen.")
# Out:
# image 1/1 /content/pose2.jpg: 640x512 1 person, 489.4ms
# Speed: 5.1ms preprocess, 489.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /content/personas5.jpg: 640x480 1 person, 482.6ms
# Speed: 3.6ms preprocess, 482.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/pose4.jpg: 640x512 4 persons, 513.6ms
# Speed: 4.0ms preprocess, 513.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
# Imagen guardada correctamente en /content/YOLO-Pre-Trained-Results/pose1_result.jpg

# %%
import matplotlib.pyplot as plt
import cv2

pose_1 = "/content/YOLO-Pre-Trained-Results/Resultado_personas5.jpg"
pose_2 = "/content/YOLO-Pre-Trained-Results/Resultado_pose2.jpg"
pose_3 = "/content/YOLO-Pre-Trained-Results/Resultado_pose4.jpg"

img_1 = cv2.imread(pose_1)
img_2 = cv2.imread(pose_2)
img_3 = cv2.imread(pose_3)

img_1_color = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
img_2_color = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)
img_3_color = cv2.cvtColor(img_3, cv2.COLOR_BGR2RGB)

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].imshow(img_1_color)
axes[0].set_title("Persona")
axes[0].axis("off")

axes[1].imshow(img_2_color)
axes[1].set_title("Pose 2")
axes[1].axis("off")

axes[2].imshow(img_3_color)
axes[2].set_title("Pose 4")
axes[2].axis("off")
# Out:
# (-0.5, 3471.5, 4623.5, -0.5)

# %%
import matplotlib.pyplot as plt
import cv2
import os

poses = ["/content/YOLO-Pre-Trained-Results/Resultado_personas5.jpg",
         "/content/YOLO-Pre-Trained-Results/Resultado_pose2.jpg",
         "/content/YOLO-Pre-Trained-Results/Resultado_pose4.jpg",
         "/content/YOLO-Pre-Trained-Results/pose1_result.jpg",]

for img_path in poses:
  img = cv2.imread(img_path)
  img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.imshow(img_color)
  plt.title(os.path.basename(img_path))
  plt.axis('off')
  plt.show()
