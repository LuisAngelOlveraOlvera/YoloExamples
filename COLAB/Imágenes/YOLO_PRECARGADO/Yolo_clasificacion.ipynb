# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.92 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/107.7 GB disk)

# %%
# !wget https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/Pelusa.jpeg
# !wget https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/pose4.jpg
# !wget https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/personas1.png
# !wget https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/personas5.jpg
# !wget https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/bus.jpg
# Out:
# --2024-09-12 01:00:44--  https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/Pelusa.jpeg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 239195 (234K) [image/jpeg]
# Saving to: ‘Pelusa.jpeg’
#
# Pelusa.jpeg         100%[===================>] 233.59K  --.-KB/s    in 0.006s
#
# 2024-09-12 01:00:44 (36.3 MB/s) - ‘Pelusa.jpeg’ saved [239195/239195]
#
# --2024-09-12 01:00:44--  https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/pose4.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# ...

# %%
from ultralytics import YOLO
import os

model = YOLO("yolov8s-cls.pt")

results = model("Pelusa.jpeg")

save_dir = "/content/YOLO-Pre-Trained-Results"
os.makedirs(save_dir, exist_ok=True)

results = results[0]

file_path = os.path.join(save_dir, "pelusa_clas.jpg")
results.save(file_path)

# Verificar si la imagen ha sido guardado o no
if os.path.exists(file_path):
    print(f"La imagen se ha guardado en: {file_path}")
else:
    print("No se ha podido guardar la imagen.")
# Out:
# ...
# 100%|██████████| 12.3M/12.3M [00:00<00:00, 160MB/s]
# image 1/1 /content/Pelusa.jpeg: 224x224 folding_chair 0.30, space_heater 0.07, dumbbell 0.05, grand_piano 0.04, rocking_chair 0.04, 263.7ms
# Speed: 96.7ms preprocess, 263.7ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 57.6MB/s]
# La imagen se ha guardado en: /content/YOLO-Pre-Trained-Results/pelusa_clas.jpg

# %%
import matplotlib.pyplot as plt
import cv2

resultado_clasificacion = "/content/YOLO-Pre-Trained-Results/pelusa_clas.jpg"
img = cv2.imread(resultado_clasificacion)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
from ultralytics import YOLO
import os

modelo = YOLO("yolov8s-cls.pt")

imagenes = ["personas1.png","personas5.jpg", "pose4.jpg", "bus.jpg"]

save_dir = "/content/YOLO-Pre-Trained-Results"
os.makedirs(save_dir, exist_ok=True)

for img_path in imagenes:
  results=modelo(img_path)
  result = results[0]
  output_image_name = f"Resultado_{os.path.basename(img_path)}"
  output_image_path = os.path.join(save_dir, output_image_name)
  result.save(output_image_path)


  if os.path.exists(file_path):
      print(f"Imagen guardada correctamente en {file_path}")
  else:
      print("No se pudo guardar la imagen.")
# Out:
# image 1/1 /content/personas1.png: 224x224 groom 0.16, bow_tie 0.15, academic_gown 0.09, neck_brace 0.07, gown 0.05, 178.5ms
# Speed: 19.4ms preprocess, 178.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Imagen guardada correctamente en /content/YOLO-Pre-Trained-Results/pelusa_clas.jpg
#
# image 1/1 /content/personas5.jpg: 224x224 hotdog 0.21, ice_lolly 0.12, sunscreen 0.10, water_bottle 0.06, water_jug 0.04, 382.1ms
# Speed: 145.4ms preprocess, 382.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Imagen guardada correctamente en /content/YOLO-Pre-Trained-Results/pelusa_clas.jpg
#
# image 1/1 /content/pose4.jpg: 224x224 maze 0.08, cliff 0.06, hatchet 0.06, binoculars 0.05, valley 0.05, 218.6ms
# Speed: 481.0ms preprocess, 218.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Imagen guardada correctamente en /content/YOLO-Pre-Trained-Results/pelusa_clas.jpg
#
# ...

# %%
import matplotlib.pyplot as plt
import cv2

clas_1 = "/content/YOLO-Pre-Trained-Results/Resultado_personas1.png"
clas_2 = "/content/YOLO-Pre-Trained-Results/Resultado_personas5.jpg"
clas_3 = "/content/YOLO-Pre-Trained-Results/Resultado_pose4.jpg"
clas_4 = "/content/YOLO-Pre-Trained-Results/Resultado_bus.jpg"

img_1 = cv2.imread(clas_1)
img_2 = cv2.imread(clas_2)
img_3 = cv2.imread(clas_3)
img_4 = cv2.imread(clas_4)

img_1_color = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
img_2_color = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)
img_3_color = cv2.cvtColor(img_3, cv2.COLOR_BGR2RGB)
img_4_color = cv2.cvtColor(img_4, cv2.COLOR_BGR2RGB)

fig, axes = plt.subplots(1, 4, figsize=(15, 5))

axes[0].imshow(img_1_color)
axes[0].set_title("Personas 1")
axes[0].axis("off")

axes[1].imshow(img_2_color)
axes[1].set_title("Persona")
axes[1].axis("off")

axes[2].imshow(img_3_color)
axes[2].set_title("Mujer")
axes[2].axis("off")

axes[3].imshow(img_4_color)
axes[3].set_title("Bus")
axes[3].axis("off")
# Out:
# (-0.5, 809.5, 1079.5, -0.5)

# %%
import matplotlib.pyplot as plt
import cv2
import os

clasificaciones = ["/content/YOLO-Pre-Trained-Results/Resultado_personas1.png",
                  "/content/YOLO-Pre-Trained-Results/Resultado_personas5.jpg",
                  "/content/YOLO-Pre-Trained-Results/Resultado_pose4.jpg",
                  "/content/YOLO-Pre-Trained-Results/pelusa_clas.jpg",
                  "/content/YOLO-Pre-Trained-Results/Resultado_bus.jpg"]

for img_path in clasificaciones:
  img = cv2.imread(img_path)
  img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.imshow(img_color)
  plt.title(os.path.basename(img_path))
  plt.axis("off")
  plt.show()
