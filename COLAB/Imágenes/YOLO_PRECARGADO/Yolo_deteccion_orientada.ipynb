# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.91 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.8/107.7 GB disk)

# %%
# !wget https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/gato2.JPG
# !wget https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/Minicky.jpeg
# Out:
# --2024-09-10 00:55:21--  https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/gato2.JPG
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66904 (65K) [image/jpeg]
# Saving to: ‘gato2.JPG’
#
# gato2.JPG           100%[===================>]  65.34K  --.-KB/s    in 0.03s
#
# 2024-09-10 00:55:21 (2.13 MB/s) - ‘gato2.JPG’ saved [66904/66904]
#
# --2024-09-10 00:55:21--  https://raw.githubusercontent.com/LuisAngelOlveraOlvera/YoloExamples/main/ImageTestYolo/Minicky.jpeg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %%
from ultralytics import YOLO
import os

# cargar el modelo pre - entrentrenado
model = YOLO('yolov8s.pt')

# Realizar una inferencia
results = model("obb_1.jpg")

# Crear un directorio donde guardaremos la imagen
save_dir = "/content/YOLO-Pre-Trained-Results"
os.makedirs(save_dir, exist_ok=True)

# Acceder al primer resultado de la lista
result = results[0]

#Guardar los resultados de la inferencia con una extensión válida (ejemplo png, jpg)
file_path = os.path.join(save_dir, "obb_deteccion_no_orientada.jpg")
result.save(file_path)

# Verificar si la imagen ha sido guardado o no
if os.path.exists(file_path):
    print(f"La imagen se ha guardado en: {file_path}")
else:
    print("No se ha podido guardar la imagen.")
# Out:
# image 1/1 /content/obb_1.jpg: 384x640 1 car, 504.8ms
# Speed: 12.1ms preprocess, 504.8ms inference, 23.4ms postprocess per image at shape (1, 3, 384, 640)
# La imagen se ha guardado en: /content/YOLO-Pre-Trained-Results/obb_deteccion_no_orientada.jpg

# %%
import matplotlib.pyplot as plt
import cv2

resultado_inferencia = "/content/YOLO-Pre-Trained-Results/obb_deteccion_no_orientada.jpg"

img = cv2.imread(resultado_inferencia)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_color)
plt.axis("off")
plt.show()

# %%
from ultralytics import YOLO
import os

# cargar el modelo pre - entrentrenado
model = YOLO('yolov8s-obb.pt')

# Realizar una inferencia
results = model("obb_1.jpg")

# Crear un directorio donde guardaremos la imagen
save_dir = "/content/YOLO-Pre-Trained-Results"
os.makedirs(save_dir, exist_ok=True)

# Acceder al primer resultado de la lista
result = results[0]

#Guardar los resultados de la inferencia con una extensión válida (ejemplo png, jpg)
file_path = os.path.join(save_dir, "obb_deteccion_orientada.jpg")
result.save(file_path)

# Verificar si la imagen ha sido guardado o no
if os.path.exists(file_path):
    print(f"La imagen se ha guardado en: {file_path}")
else:
    print("No se ha podido guardar la imagen.")
# Out:
# ...
# 100%|██████████| 22.2M/22.2M [00:00<00:00, 60.8MB/s]
# image 1/1 /content/obb_1.jpg: 576x1024 1389.3ms
# Speed: 5.2ms preprocess, 1389.3ms inference, 7.4ms postprocess per image at shape (1, 3, 576, 1024)
# La imagen se ha guardado en: /content/YOLO-Pre-Trained-Results/obb_deteccion_orientada.jpg

# %%
import matplotlib.pyplot as plt
import cv2

resultado_inferencia = "/content/YOLO-Pre-Trained-Results/obb_deteccion_orientada.jpg"

img = cv2.imread(resultado_inferencia)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_color)
plt.axis("off")
plt.show()

# %%
# Procesar 3 imágenes al mismo tiempo
from ultralytics import YOLO
import os

# cargar el modelo
modelo = YOLO('yolov8s-obb.pt')

# Seleccionar las imágenes a procesar
imagenes = ["autos_1.jpeg", "barcos_1.jpeg", "gato2.JPG", "obb_2.jpg"]

# Crear carpeta
save_dir = "/content/YOLO-Pre-Trained-Results_obb"
os.makedirs(save_dir, exist_ok=True)

# Ciclo for para hacer las inferencias
for img_path in imagenes:
  results=modelo(img_path)
  result = results[0]
  output_image_name = f"Resultado_{os.path.basename(img_path)}"
  output_image_path = os.path.join(save_dir, output_image_name)
  result.save(output_image_path)

    # Verificar si los resultados fueron guardados
  if os.path.exists(file_path):
      print(f"Imagen guardada correctamente en {file_path}")
  else:
      print("No se pudo guardar la imagen.")
# Out:
# image 1/1 /content/autos_1.jpeg: 1024x1024 1888.9ms
# Speed: 10.8ms preprocess, 1888.9ms inference, 2.6ms postprocess per image at shape (1, 3, 1024, 1024)
# Imagen guardada correctamente en /content/YOLO-Pre-Trained-Results/obb_deteccion_orientada.jpg
#
# image 1/1 /content/barcos_1.jpeg: 1024x1024 2256.0ms
# Speed: 14.0ms preprocess, 2256.0ms inference, 2.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Imagen guardada correctamente en /content/YOLO-Pre-Trained-Results/obb_deteccion_orientada.jpg
#
# image 1/1 /content/gato2.JPG: 608x1024 (no detections), 868.2ms
# Speed: 5.5ms preprocess, 868.2ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 1024)
# Imagen guardada correctamente en /content/YOLO-Pre-Trained-Results/obb_deteccion_orientada.jpg
#
# image 1/1 /content/obb_2.jpg: 704x1024 1047.3ms
# Speed: 5.5ms preprocess, 1047.3ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1024)
# ...

# %%
import matplotlib.pyplot as plt
import cv2

det_1_obb = "/content/YOLO-Pre-Trained-Results_obb/Resultado_autos_1.jpeg"
det_2_obb = "/content/YOLO-Pre-Trained-Results_obb/Resultado_barcos_1.jpeg"
det_3_obb = "/content/YOLO-Pre-Trained-Results_obb/Resultado_gato2.JPG"
det_4_obb = "/content/YOLO-Pre-Trained-Results_obb/Resultado_obb_2.jpg"

# Lista de rutas a las imágenes
det_images = [det_1_obb, det_2_obb, det_3_obb, det_4_obb]

# Crear una figura con 2 filas y 2 columnas de subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 5))

# Leer y mostrar las imágenes en los subplots correspondientes
for i, ax in enumerate(axes.flat):
    img = cv2.imread(det_images[i])
    img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ax.imshow(img_color)
    ax.set_title(f"Obb {i+1}")
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
# Procesar 3 imágenes al mismo tiempo
from ultralytics import YOLO
import os

# cargar el modelo
modelo = YOLO('yolov8s.pt')

# Seleccionar las imágenes a procesar
imagenes = ["autos_1.jpeg", "barcos_1.jpeg", "gato2.JPG", "obb_2.jpg"]

# Crear carpeta
save_dir = "/content/YOLO-Pre-Trained-Results_deteccion"
os.makedirs(save_dir, exist_ok=True)

# Ciclo for para hacer las inferencias
for img_path in imagenes:
  results=modelo(img_path)
  result = results[0]
  output_image_name = f"Resultado_{os.path.basename(img_path)}"
  output_image_path = os.path.join(save_dir, output_image_name)
  result.save(output_image_path)

    # Verificar si los resultados fueron guardados
  if os.path.exists(file_path):
      print(f"Imagen guardada correctamente en {file_path}")
  else:
      print("No se pudo guardar la imagen.")
# Out:
# image 1/1 /content/autos_1.jpeg: 640x640 1 person, 33 cars, 1 bus, 1 truck, 566.5ms
# Speed: 3.8ms preprocess, 566.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Imagen guardada correctamente en /content/YOLO-Pre-Trained-Results/obb_deteccion_orientada.jpg
#
# image 1/1 /content/barcos_1.jpeg: 640x640 17 boats, 1 bird, 544.9ms
# Speed: 3.6ms preprocess, 544.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Imagen guardada correctamente en /content/YOLO-Pre-Trained-Results/obb_deteccion_orientada.jpg
#
# image 1/1 /content/gato2.JPG: 384x640 1 cat, 338.0ms
# Speed: 3.2ms preprocess, 338.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Imagen guardada correctamente en /content/YOLO-Pre-Trained-Results/obb_deteccion_orientada.jpg
#
# image 1/1 /content/obb_2.jpg: 448x640 1 car, 1 traffic light, 396.6ms
# Speed: 2.6ms preprocess, 396.6ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# ...

# %%
import matplotlib.pyplot as plt
import cv2

det_1_obb = "/content/YOLO-Pre-Trained-Results_deteccion/Resultado_autos_1.jpeg"
det_2_obb = "/content/YOLO-Pre-Trained-Results_deteccion/Resultado_barcos_1.jpeg"
det_3_obb = "/content/YOLO-Pre-Trained-Results_deteccion/Resultado_gato2.JPG"
det_4_obb = "/content/YOLO-Pre-Trained-Results_deteccion/Resultado_obb_2.jpg"

# Lista de rutas a las imágenes
det_images = [det_1_obb, det_2_obb, det_3_obb, det_4_obb]

# Crear una figura con 2 filas y 2 columnas de subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 5))

# Leer y mostrar las imágenes en los subplots correspondientes
for i, ax in enumerate(axes.flat):
    img = cv2.imread(det_images[i])
    img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ax.imshow(img_color)
    ax.set_title(f"Obb {i+1}")
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import cv2

autos_obb = "/content/YOLO-Pre-Trained-Results_obb/Resultado_autos_1.jpeg"
auto_deteccion = "/content/YOLO-Pre-Trained-Results_deteccion/Resultado_autos_1.jpeg"

img_det = cv2.imread(auto_deteccion)
img_color_det = cv2.cvtColor(img_det, cv2.COLOR_BGR2RGB)

img_obb = cv2.imread(autos_obb)
img_color_obb = cv2.cvtColor(img_obb, cv2.COLOR_BGR2RGB)


fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].imshow(img_color_det)
axes[0].set_title("Detección")
axes[0].axis("off")

axes[1].imshow(img_color_obb)
axes[1].set_title("Detección OBB")
axes[1].axis("off")
# Out:
# (-0.5, 1279.5, 1279.5, -0.5)

# %%
import matplotlib.pyplot as plt
import cv2

barcos_obb = "/content/YOLO-Pre-Trained-Results_obb/Resultado_barcos_1.jpeg"
barcos_deteccion = "/content/YOLO-Pre-Trained-Results_deteccion/Resultado_barcos_1.jpeg"

img_det = cv2.imread(barcos_deteccion)
img_color_det = cv2.cvtColor(img_det, cv2.COLOR_BGR2RGB)

img_obb = cv2.imread(barcos_obb)
img_color_obb = cv2.cvtColor(img_obb, cv2.COLOR_BGR2RGB)


fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].imshow(img_color_det)
axes[0].set_title("Detección")
axes[0].axis("off")

axes[1].imshow(img_color_obb)
axes[1].set_title("Detección OBB")
axes[1].axis("off")
# Out:
# (-0.5, 1279.5, 1279.5, -0.5)

# %%
import matplotlib.pyplot as plt
import cv2

gato2_obb = "/content/YOLO-Pre-Trained-Results_obb/Resultado_gato2.JPG"
gato2_deteccion = "/content/YOLO-Pre-Trained-Results_deteccion/Resultado_gato2.JPG"

img_det = cv2.imread(gato2_deteccion)
img_color_det = cv2.cvtColor(img_det, cv2.COLOR_BGR2RGB)

img_obb = cv2.imread(gato2_obb)
img_color_obb = cv2.cvtColor(img_obb, cv2.COLOR_BGR2RGB)


fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].imshow(img_color_det)
axes[0].set_title("Detección")
axes[0].axis("off")

axes[1].imshow(img_color_obb)
axes[1].set_title("Detección OBB")
axes[1].axis("off")
# Out:
# (-0.5, 1068.5, 605.5, -0.5)

# %%
import matplotlib.pyplot as plt
import cv2

obb_2_det = "/content/YOLO-Pre-Trained-Results_obb/Resultado_obb_2.jpg"
obb_2_obb = "/content/YOLO-Pre-Trained-Results_deteccion/Resultado_obb_2.jpg"

img_det = cv2.imread(obb_2_det)
img_color_det = cv2.cvtColor(img_det, cv2.COLOR_BGR2RGB)

img_obb = cv2.imread(obb_2_obb)
img_color_obb = cv2.cvtColor(img_obb, cv2.COLOR_BGR2RGB)


fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].imshow(img_color_det)
axes[0].set_title("Detección")
axes[0].axis("off")

axes[1].imshow(img_color_obb)
axes[1].set_title("Detección OBB")
axes[1].axis("off")
# Out:
# (-0.5, 719.5, 479.5, -0.5)
