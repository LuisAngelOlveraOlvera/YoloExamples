# %%
# !pip install oidv6
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 49.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 kB 4.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# ...

# %%
# !wget https://storage.googleapis.com/openimages/2018_04/class-descriptions-boxable.csv

# !wget https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv

# !wget https://storage.googleapis.com/openimages/2018_04/validation/validation-annotations-bbox.csv

# !wget https://storage.googleapis.com/openimages/2018_04/test/test-annotations-bbox.csv
# Out:
# --2024-11-05 14:22:17--  https://storage.googleapis.com/openimages/2018_04/class-descriptions-boxable.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.31.207, 142.251.18.207, 142.250.153.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.31.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11255 (11K) [text/csv]
# Saving to: ‘class-descriptions-boxable.csv’
#
# class-descriptions- 100%[===================>]  10.99K  --.-KB/s    in 0s
#
# 2024-11-05 14:22:17 (65.5 MB/s) - ‘class-descriptions-boxable.csv’ saved [11255/11255]
#
# --2024-11-05 14:22:17--  https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.31.207, 142.251.18.207, 142.250.153.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.31.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "Cat" --limit 3500
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 14:35:42] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 14:35:42] Checking command line arguments for validity ...
# [2024-11-04 14:35:42] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 14:35:42] Downloading "cat" ...
#     File "class-descriptions-boxable.csv" not found ...
#         Do you want to download the missing file? [Y/n] Y
#         Automatic download ... 24 out of 24 (100%)
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "Human arm" --limit 3500
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 15:49:14] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 15:49:14] Checking command line arguments for validity ...
# [2024-11-04 15:49:14] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 15:49:14] Downloading "human arm" ...
#     Extracting data from "oidv6-train-annotations-bbox.csv" ...
#     Total "train" images 41380 ... of which will be loaded 3500 ...
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "Human body" --limit 3500
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 16:58:56] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 16:58:56] Checking command line arguments for validity ...
# [2024-11-04 16:58:56] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 16:58:56] Downloading "human body" ...
#     Extracting data from "oidv6-train-annotations-bbox.csv" ...
#     Total "train" images 45398 ... of which will be loaded 3500 ...
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "Human eye" --limit 3500
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 18:09:17] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 18:09:17] Checking command line arguments for validity ...
# [2024-11-04 18:09:17] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 18:09:17] Downloading "human eye" ...
#     Extracting data from "oidv6-train-annotations-bbox.csv" ...
#     Total "train" images 23743 ... of which will be loaded 3500 ...
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "Human Face" --limit 3500
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 19:20:49] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 19:20:49] Checking command line arguments for validity ...
# [2024-11-04 19:20:49] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-04 19:20:49] Downloading "human face" ...
#     Extracting data from "oidv6-train-annotations-bbox.csv" ...
#     Total "train" images 331627 ... of which will be loaded 3500 ...
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "Human hand" --limit 3500

# %%
# !oidv6 downloader --dataset open_images --classes "Human mouth" --limit 3500
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-06 14:59:54] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-11-06 14:59:54] Checking command line arguments for validity ...
# [2024-11-06 14:59:54] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-06 14:59:54] Downloading "human mouth" ...
#     File "class-descriptions-boxable.csv" not found ...
#         Do you want to download the missing file? [Y/n] y
#         Automatic download ... 24 out of 24 (100%)
# ...

# %%
# !zip -r human_mouth.zip /content/open_images/train/human_mouth
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   adding: content/open_images/train/human_mouth/labels/195f9d1a929dd4c4.txt (deflated 28%)
#   adding: content/open_images/train/human_mouth/labels/14a7139ff4203788.txt (deflated 2%)
#   adding: content/open_images/train/human_mouth/labels/18e5c8c053aa8524.txt (deflated 13%)
#   adding: content/open_images/train/human_mouth/labels/06ce513a977b1506.txt (deflated 23%)
#   adding: content/open_images/train/human_mouth/labels/190b404d4baf6b8a.txt (deflated 27%)
#   adding: content/open_images/train/human_mouth/labels/007816f453301e07.txt (stored 0%)
#   adding: content/open_images/train/human_mouth/labels/05b761121607d3a5.txt (deflated 6%)
#   adding: content/open_images/train/human_mouth/labels/0620cb06ec92cf74.txt (stored 0%)
#   adding: content/open_images/train/human_mouth/labels/0ce70aaff18a3afc.txt (deflated 5%)
#   adding: content/open_images/train/human_mouth/labels/09ef21b7e7188d0c.txt (stored 0%)
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "car" --limit 3500
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-06 16:28:53] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-11-06 16:28:53] Checking command line arguments for validity ...
# [2024-11-06 16:28:53] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-06 16:28:53] Downloading "car" ...
#     Extracting data from "oidv6-train-annotations-bbox.csv" ...
#     Total "train" images 89465 ... of which will be loaded 3500 ...
# ...

# %%
# !zip -r human_car.zip /content/open_images/train/car
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   adding: content/open_images/train/car/labels/01a0970c07141e7b.txt (stored 0%)
#   adding: content/open_images/train/car/labels/04f4b46353ca731d.txt (stored 0%)
#   adding: content/open_images/train/car/labels/0470d954f282fc89.txt (deflated 25%)
#   adding: content/open_images/train/car/labels/009bc6fcdf25423d.txt (deflated 25%)
#   adding: content/open_images/train/car/labels/04885ecf0c085e77.txt (deflated 38%)
#   adding: content/open_images/train/car/labels/0057302186980f9e.txt (deflated 6%)
#   adding: content/open_images/train/car/labels/0340d557873ff1e3.txt (deflated 52%)
#   adding: content/open_images/train/car/labels/04e583752436588b.txt (deflated 4%)
#   adding: content/open_images/train/car/labels/06b519f5ce3322e6.txt (deflated 39%)
#   adding: content/open_images/train/car/labels/081a5c80a0a7dac6.txt (deflated 13%)
#   adding: content/open_images/train/car/labels/003d1fc0b14d5133.txt (deflated 37%)
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "person" --limit 3500
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-07 15:56:49] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-11-07 15:56:49] Checking command line arguments for validity ...
# [2024-11-07 15:56:49] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-11-07 15:56:49] Downloading "person" ...
#     File "class-descriptions-boxable.csv" not found ...
#         Do you want to download the missing file? [Y/n] y
#         Automatic download ... 24 out of 24 (100%)
# ...

# %%
# !zip -r person.zip /content/open_images/train/person
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   adding: content/open_images/train/person/0075679a7838fec7.jpg (deflated 0%)
#   adding: content/open_images/train/person/0101c085abc25682.jpg (deflated 0%)
#   adding: content/open_images/train/person/028c0f67c4106a87.jpg (deflated 0%)
#   adding: content/open_images/train/person/0257a8306e9595b1.jpg (deflated 1%)
#   adding: content/open_images/train/person/002f089ff8ec89a5.jpg (deflated 0%)
#   adding: content/open_images/train/person/02c2e880229f8d8f.jpg (deflated 0%)
#   adding: content/open_images/train/person/00025431f1dca713.jpg (deflated 0%)
#   adding: content/open_images/train/person/021bf9af95f4c457.jpg (deflated 0%)
#   adding: content/open_images/train/person/00b5981a9af8155e.jpg (deflated 1%)
#   adding: content/open_images/train/person/0012d2efdbe3cb40.jpg (deflated 1%)
#   adding: content/open_images/train/person/00db4a4663710a87.jpg (deflated 0%)
# ...

# %%
import requests

url = "https://uaq088-my.sharepoint.com/:u:/g/personal/lolvera68_lms_uaq_mx/EfqNVTSems5Cn0koN_AJxq0BGWZ0XJGY8XS8VatT8TJegw?e=D2M12L"
response = requests.get(url)

with open("OpenImagesV2.zip", "wb") as file:
    file.write(response.content)

print("File downloaded successfully!")
# Out:
# File downloaded successfully!

# %%
import zipfile

# Descomprimir el archivo ZIP
with zipfile.ZipFile("OpenImagesV2.zip", 'r') as zip_ref:
    zip_ref.extractall()

print("Archivo descomprimido exitosamente!")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-3-ce666442f4cf> in <cell line: 4>()
#       2
#       3 # Descomprimir el archivo ZIP
# ----> 4 with zipfile.ZipFile("OpenImagesV2.zip", 'r') as zip_ref:
#       5     zip_ref.extractall()
#       6
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1270         try:
#    1271             if mode == 'r':
# -> 1272                 self._RealGetContents()
#    1273             elif mode in ('w', 'x'):
#    1274                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.10/zipfile.py in _RealGetContents(self)
#    1337             raise BadZipFile("File is not a zip file")
#    1338         if not endrec:
# -> 1339             raise BadZipFile("File is not a zip file")
#    1340         if self.debug > 1:
# ...
