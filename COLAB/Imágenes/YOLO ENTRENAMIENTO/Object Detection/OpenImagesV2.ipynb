# %%
# !pip install oidv6
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# ...

# %%
# !wget https://storage.googleapis.com/openimages/2018_04/class-descriptions-boxable.csv

# !wget https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv

# !wget https://storage.googleapis.com/openimages/2018_04/validation/validation-annotations-bbox.csv

# !wget https://storage.googleapis.com/openimages/2018_04/test/test-annotations-bbox.csv
# Out:
# --2024-10-25 05:10:12--  https://storage.googleapis.com/openimages/2018_04/class-descriptions-boxable.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.0.91, 172.217.7.59, 172.217.12.27, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.0.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11255 (11K) [text/csv]
# Saving to: ‘class-descriptions-boxable.csv’
#
# class-descriptions- 100%[===================>]  10.99K  --.-KB/s    in 0s
#
# 2024-10-25 05:10:12 (95.3 MB/s) - ‘class-descriptions-boxable.csv’ saved [11255/11255]
#
# --2024-10-25 05:10:12--  https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.0.91, 172.217.7.59, 172.217.12.27, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.0.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "Cat" "Person" "Tree", "Pen", "Human Face", "Human Hand", "Human Arm", "Book", "Mobile phone" --limit 2000
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 05:12:31] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 05:12:31] Checking command line arguments for validity ...
# [2024-10-25 05:12:31] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 05:12:31] Downloading "cat" ...
#     File "class-descriptions-boxable.csv" not found ...
#         Do you want to download the missing file? [Y/n] Y
#         Automatic download ... 24 out of 24 (100%)
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "Human Face" --limit 10
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 07:06:08] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 07:06:08] Checking command line arguments for validity ...
# [2024-10-25 07:06:08] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 07:06:08] Downloading "human face" ...
#     Extracting data from "oidv6-train-annotations-bbox.csv" ...
#     Total "train" images 331627 ... of which will be loaded 10 ...
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "Human arm" --limit 10
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 07:07:35] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 07:07:35] Checking command line arguments for validity ...
# [2024-10-25 07:07:35] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 07:07:35] Downloading "human arm" ...
#     Extracting data from "oidv6-train-annotations-bbox.csv" ...
#     Total "train" images 41380 ... of which will be loaded 10 ...
# ...

# %%
# !oidv6 downloader --dataset open_images --classes "Human eye" --limit 10
# Out:
# ----------------------------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 07:09:20] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 07:09:20] Checking command line arguments for validity ...
# [2024-10-25 07:09:20] Creating Directories for Metadata ...
# ----------------------------------------------------------------------------------------------------
# [2024-10-25 07:09:20] Downloading "human eye" ...
#     Extracting data from "oidv6-train-annotations-bbox.csv" ...
#     Total "train" images 23743 ... of which will be loaded 10 ...
# ...
